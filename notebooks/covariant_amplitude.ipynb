# %%
using SymPy
using LinearAlgebra
using Test

# %%
import PyCall
PyCall.pyimport_conda("sympy.physics.quantum.spin", "sympy")
import_from(sympy.physics.quantum.spin, (:WignerD, :wignerd), typ=:Any)
PyCall.pyimport_conda("sympy.physics.wigner",       "sympy")
import_from(sympy.physics.wigner)

# %% [markdown]
# ## Dirac matrives

# %%
σx = [Sym(0) 1; 1 0]
σy = [Sym(0) -1im; 1im 0]
σz = [1 Sym(0); 0 -1]
id  = Matrix(I,2,2)
id4  = Matrix(I,4,4)
z = zeros(Int, 2,2);

# %%
γ0 = [id z; z -id]
γ1 = [z σx; -σx z]
γ2 = [z σy; -σy z]
γ3 = [z σz; -σz z];
γ = (γ1,γ2,γ3,γ0);

# %%
sp(a,b) = a[4]*b[4]-sum(a[1:3].*b[1:3])
# Out:
# sp (generic function with 1 method)

# %%
@test sp(γ,γ) == 4*Matrix(I,4,4)
# Out:
# Test Passed

# %%
m0,m1,m2,m3 = @vars m0 m1 m2 m3 positive=true
σ1,σ2,σ3 = @vars σ_1 σ_2 σ_3
θhat12, θhat23 = @vars θhat_12 θhat_23
cθhat12, sθhat12 = cos(θhat12), sin(θhat12)
cθhat23, sθhat23 = cos(θhat23), sin(θhat23)
summsq = sum([m0,m1,m2,m3].^2)
# Out:
#   2     2     2     2
# m0  + m1  + m2  + m3

# %%
E2, = @vars E2 positive=true
Ep, Em = sqrt(E2+m2), sqrt(E2-m2)
# Out:
# (sqrt(E2 + m2), sqrt(E2 - m2))

# %% [markdown]
# ## Spinors
#  * index `b` for $\Xi_b$
#  * index `p` for p

# %%
ub⁺ = [1,0,0,0] # dropped sqrt(2m2)
ub⁻ = [0,1,0,0] 
up⁺ = [0,Ep,0,Em]
up⁻ = [-Ep,0,Em,0]
# Out:
# 4-element Array{Sym,1}:
#  -sqrt(E2 + m2)
#               0
#   sqrt(E2 - m2)
#               0

# %% [markdown]
# ## Four vectors in components
# calculated in CM frame in KK symmetric configuration

# %%
λ1,λ2,λ3 = @vars λ_1 λ_2 λ_3
# 
pb = [0,0,0,2m0^2] # droped /2m0
pp = [0,0,-λ2,(m0^2+m2^2-σ2)] # droped /2m0
pK1 = [λ1*sθhat12,0,λ1*cθhat12, (m0^2+m1^2-σ1)] # droped /2m0
pK3 = [-λ3*sθhat23,0,λ3*cθhat23, (m0^2+m3^2-σ3)] # droped /2m0
# Out:
# 4-element Array{Sym,1}:
#  -λ_3*sin(θhat_23)
#                  0
#   λ_3*cos(θhat_23)
#  m0^2 + m3^2 - σ_3

# %%
term1pp = transpose(up⁺)*γ0*(sp(pK1+pp,γ)+id4*2m0*sqrt(σ3))*ub⁺
term1mm = transpose(up⁻)*γ0*(sp(pK1+pp,γ)+id4*2m0*sqrt(σ3))*ub⁻
term1pp - term1mm == 0
# Out:
# true

# %%
term1pp
# Out:
#        _________
# -λ_1*\/ E2 - m2 *sin(θhat_12)

# %%
subs(term1pp,
    Em=>λ2^2)
# Out:
#         2
# -λ_1*λ_2 *sin(θhat_12)

# %%
term1pm = transpose(up⁺)*γ0*(sp(pK1+pp,γ)+id4*2m0*sqrt(σ3))*ub⁻
term1mp = transpose(up⁻)*γ0*(sp(pK1+pp,γ)+id4*2m0*sqrt(σ3))*ub⁺
simplify(term1mp + term1pm) == 0
# Out:
# true

# %%
term1pm
# Out:
#     _________                               _________ /    2          _____
# - \/ E2 - m2 *(-λ_1*cos(θhat_12) + λ_2) + \/ E2 + m2 *\2*m0  + 2*m0*\/ σ_3  +
#
#   2     2            \
# m1  + m2  - σ_1 - σ_2/

# %%
subs(term1pm, σ1=>sum([m0,m1,m2,m3].^2)-σ2-σ3)
# Out:
#     _________                               _________ /  2          _____
# - \/ E2 - m2 *(-λ_1*cos(θhat_12) + λ_2) + \/ E2 + m2 *\m0  + 2*m0*\/ σ_3  - m3
#
# 2      \
#   + σ_3/

# %%
subs(subs(subs(term1pm,
    σ1=>summsq-σ2-σ3),
    Em=>λ2^2),
    Ep=>2m0*(pp[4]+2m0*m2))
# Out:
#      /  2               2      \ /  2          _____     2      \      2
# 2*m0*\m0  + 2*m0*m2 + m2  - σ_2/*\m0  + 2*m0*\/ σ_3  - m3  + σ_3/ - λ_2 *(-λ_1
#
#
# *cos(θhat_12) + λ_2)

# %% [markdown]
# ## Angular functions

# %%
λ(x,y,z) = x^2+y^2+z^2-2x*y-2y*z-2z*x

# %%
cosζ221n = 2m2^2*(σ3-m0^2-m3^2)+(m0^2+m2^2-σ2)*(σ1-m2^2-m3^2)
cosζ221d_sq = λ(m0^2,m2^2,σ2)*λ(m3^2,m2^2,σ1)
factor(subs(factor(cosζ221d_sq-cosζ221n^2),σ3=>summsq-σ1-σ2)) # numerator of sin
# Out:
#      2 /  4   2     2   2   2     2   2   2     2   2         2   2   2     2
# -4*m2 *\m0 *m3  - m0 *m1 *m2  - m0 *m1 *m3  + m0 *m1 *σ_1 - m0 *m2 *m3  + m0 *
#
#   2         2   4     2   2         2   2         2             4   2     2
# m2 *σ_2 + m0 *m3  - m0 *m3 *σ_1 - m0 *m3 *σ_2 - m0 *σ_1*σ_2 + m1 *m2  + m1 *m2
#
# 4     2   2   2     2   2         2   2         2   2         2             2
#   - m1 *m2 *m3  - m1 *m2 *σ_1 - m1 *m2 *σ_2 + m1 *m3 *σ_2 - m1 *σ_1*σ_2 + m2 *
#
#   2         2             2              2              2\
# m3 *σ_1 - m2 *σ_1*σ_2 - m3 *σ_1*σ_2 + σ_1 *σ_2 + σ_1*σ_2 /

# %%
ϕ = -factor(λ(λ(σ1,m1^2,m0^2),λ(σ2,m2^2,m0^2),λ(summsq-σ1-σ2,m3^2,m0^2)))/(16m0^2)
# Out:
#     4   2     2   2   2     2   2   2     2   2         2   2   2     2   2
# - m0 *m3  + m0 *m1 *m2  + m0 *m1 *m3  - m0 *m1 *σ_1 + m0 *m2 *m3  - m0 *m2 *σ_
#
#       2   4     2   2         2   2         2             4   2     2   4
# 2 - m0 *m3  + m0 *m3 *σ_1 + m0 *m3 *σ_2 + m0 *σ_1*σ_2 - m1 *m2  - m1 *m2  + m1
#
# 2   2   2     2   2         2   2         2   2         2             2   2
#  *m2 *m3  + m1 *m2 *σ_1 + m1 *m2 *σ_2 - m1 *m3 *σ_2 + m1 *σ_1*σ_2 - m2 *m3 *σ_
#
#       2             2              2              2
# 1 + m2 *σ_1*σ_2 + m3 *σ_1*σ_2 - σ_1 *σ_2 - σ_1*σ_2

# %%
cosθ23n = 2σ1*(σ3-m1^2-m2^2)-(σ1+m2^2-m3^2)*(m0^2-σ1-m1^2)
cosθ23d_sq = λ(m0^2,m1^2,σ1)*λ(σ1,m2^2,m3^2)
factor(subs(factor(cosθ23d_sq-cosθ23n^2),σ3=>summsq-σ1-σ2)) # numerator of sin
# Out:
#        /  4   2     2   2   2     2   2   2     2   2         2   2   2     2
# -4*σ_1*\m0 *m3  - m0 *m1 *m2  - m0 *m1 *m3  + m0 *m1 *σ_1 - m0 *m2 *m3  + m0 *
#
#   2         2   4     2   2         2   2         2             4   2     2
# m2 *σ_2 + m0 *m3  - m0 *m3 *σ_1 - m0 *m3 *σ_2 - m0 *σ_1*σ_2 + m1 *m2  + m1 *m2
#
# 4     2   2   2     2   2         2   2         2   2         2             2
#   - m1 *m2 *m3  - m1 *m2 *σ_1 - m1 *m2 *σ_2 + m1 *m3 *σ_2 - m1 *σ_1*σ_2 + m2 *
#
#   2         2             2              2              2\
# m3 *σ_1 - m2 *σ_1*σ_2 - m3 *σ_1*σ_2 + σ_1 *σ_2 + σ_1*σ_2 /

# %%
cosζ231n = 2m2^2*(m3^2+m1^2-σ2)+(σ3-m2^2-m1^2)*(σ1-m2^2-m3^2)
cosζ231d_sq = λ(σ3,m1^2,m2^2)*λ(σ1,m2^2,m3^2)
factor(subs(factor(cosζ231d_sq-cosζ231n^2),σ3=>summsq-σ1-σ2))
# Out:
#      2 /  4   2     2   2   2     2   2   2     2   2         2   2   2     2
# -4*m2 *\m0 *m3  - m0 *m1 *m2  - m0 *m1 *m3  + m0 *m1 *σ_1 - m0 *m2 *m3  + m0 *
#
#   2         2   4     2   2         2   2         2             4   2     2
# m2 *σ_2 + m0 *m3  - m0 *m3 *σ_1 - m0 *m3 *σ_2 - m0 *σ_1*σ_2 + m1 *m2  + m1 *m2
#
# 4     2   2   2     2   2         2   2         2   2         2             2
#   - m1 *m2 *m3  - m1 *m2 *σ_1 - m1 *m2 *σ_2 + m1 *m3 *σ_2 - m1 *σ_1*σ_2 + m2 *
#
#   2         2             2              2              2\
# m3 *σ_1 - m2 *σ_1*σ_2 - m3 *σ_1*σ_2 + σ_1 *σ_2 + σ_1*σ_2 /

# %%
cosθhat12n = (m0^2+m1^2-σ1)*(m0^2+m2^2-σ2) - 2m0^2*(σ3-m1^2-m2^2)
cosθhat12d_sq = λ(m0^2,m2^2,σ2)*λ(m0^2,σ1,m1^2)
factor(subs(factor(cosθhat12d_sq-cosθhat12n^2),σ3=>summsq-σ1-σ2)) # numerator of sin
# Out:
#      2 /  4   2     2   2   2     2   2   2     2   2         2   2   2     2
# -4*m0 *\m0 *m3  - m0 *m1 *m2  - m0 *m1 *m3  + m0 *m1 *σ_1 - m0 *m2 *m3  + m0 *
#
#   2         2   4     2   2         2   2         2             4   2     2
# m2 *σ_2 + m0 *m3  - m0 *m3 *σ_1 - m0 *m3 *σ_2 - m0 *σ_1*σ_2 + m1 *m2  + m1 *m2
#
# 4     2   2   2     2   2         2   2         2   2         2             2
#   - m1 *m2 *m3  - m1 *m2 *σ_1 - m1 *m2 *σ_2 + m1 *m3 *σ_2 - m1 *σ_1*σ_2 + m2 *
#
#   2         2             2              2              2\
# m3 *σ_1 - m2 *σ_1*σ_2 - m3 *σ_1*σ_2 + σ_1 *σ_2 + σ_1*σ_2 /

# %% [markdown]
# ### Substiture expression for the amplitude
# $$
# A_{\nu,\lambda} = d_{\nu,\lambda}^{1/2}(\hat\theta_{1(2)}+\theta_{23}-\zeta^2_{2(1)})
# $$

# %%
α,β,δ = @vars α β δ
# Out:
# (α, β, δ)

# %%
expand(sympy.expand_trig(cos(α+β-δ)))
# Out:
# -sin(α)*sin(β)*cos(δ) + sin(α)*sin(δ)*cos(β) + sin(β)*sin(δ)*cos(α) + cos(α)*c
# os(β)*cos(δ)

# %%
# expression for the half angle sum (α+β-δ)/2
v = simplify(subs(subs(subs(subs(subs(subs(expand(sympy.expand_trig(cos(α+β-δ))),
    sin(α)=>2m0*ϕ),
    cos(α)=>cosθhat12n),
    sin(β)=>2sqrt(σ1)*ϕ),
    cos(β)=>cosθ23n),
    sin(δ)=>2m2*ϕ),
    cos(δ)=>cosζ221n))
# Out:
#
#           /      /  2     2      \   /    2     2      \ /  2     2      \\ /
# - 4*m0*m2*\2*σ_1*\m1  + m2  - σ_3/ - \- m0  + m1  + σ_1/*\m2  - m3  + σ_1//*\-
#
#
#    4   2     2   2   2     2   2   2     2   2         2   2   2     2   2
#  m0 *m3  + m0 *m1 *m2  + m0 *m1 *m3  - m0 *m1 *σ_1 + m0 *m2 *m3  - m0 *m2 *σ_2
#
#
#      2   4     2   2         2   2         2             4   2     2   4     2
#  - m0 *m3  + m0 *m3 *σ_1 + m0 *m3 *σ_2 + m0 *σ_1*σ_2 - m1 *m2  - m1 *m2  + m1
#
#
#    2   2     2   2         2   2         2   2         2             2   2
# *m2 *m3  + m1 *m2 *σ_1 + m1 *m2 *σ_2 - m1 *m3 *σ_2 + m1 *σ_1*σ_2 - m2 *m3 *σ_1
#
#                                                    2
#      2             2              2              2\           _____ /    2 /
#  + m2 *σ_1*σ_2 + m3 *σ_1*σ_2 - σ_1 *σ_2 - σ_1*σ_2 /  + 4*m0*\/ σ_1 *\2*m2 *\m0
#
#
# 2     2      \   /  2     2      \ /  2     2      \\ /    4   2     2   2   2
#   + m3  - σ_3/ + \m0  + m2  - σ_2/*\m2  + m3  - σ_1//*\- m0 *m3  + m0 *m1 *m2
#
#
#      2   2   2     2   2         2   2   2     2   2         2   4     2   2
#  + m0 *m1 *m3  - m0 *m1 *σ_1 + m0 *m2 *m3  - m0 *m2 *σ_2 - m0 *m3  + m0 *m3 *σ
#
#
#        2   2         2             4   2     2   4     2   2   2     2   2
# _1 + m0 *m3 *σ_2 + m0 *σ_1*σ_2 - m1 *m2  - m1 *m2  + m1 *m2 *m3  + m1 *m2 *σ_1
#
#
#      2   2         2   2         2             2   2         2             2
#  + m1 *m2 *σ_2 - m1 *m3 *σ_2 + m1 *σ_1*σ_2 - m2 *m3 *σ_1 + m2 *σ_1*σ_2 + m3 *σ
#
#                              2
#             2              2\           _____ /    2 /  2     2      \   /  2
# _1*σ_2 - σ_1 *σ_2 - σ_1*σ_2 /  + 4*m2*\/ σ_1 *\2*m0 *\m1  + m2  - σ_3/ + \m0
#
#
#     2      \ /  2     2      \\ /    4   2     2   2   2     2   2   2     2
# + m1  - σ_1/*\m0  + m2  - σ_2//*\- m0 *m3  + m0 *m1 *m2  + m0 *m1 *m3  - m0 *m
#
#
#  2         2   2   2     2   2         2   4     2   2         2   2         2
# 1 *σ_1 + m0 *m2 *m3  - m0 *m2 *σ_2 - m0 *m3  + m0 *m3 *σ_1 + m0 *m3 *σ_2 + m0
#
#
#              4   2     2   4     2   2   2     2   2         2   2         2
# *σ_1*σ_2 - m1 *m2  - m1 *m2  + m1 *m2 *m3  + m1 *m2 *σ_1 + m1 *m2 *σ_2 - m1 *m
#
#
#  2         2             2   2         2             2              2
# 3 *σ_2 + m1 *σ_1*σ_2 - m2 *m3 *σ_1 + m2 *σ_1*σ_2 + m3 *σ_1*σ_2 - σ_1 *σ_2 - σ_
#
#        2
#      2\    /    2 /  2     2      \   /  2     2      \ /  2     2      \\ /
# 1*σ_2 /  + \2*m0 *\m1  + m2  - σ_3/ + \m0  + m1  - σ_1/*\m0  + m2  - σ_2//*\2*
#
#
#   2 /  2     2      \   /  2     2      \ /  2     2      \\ /      /  2     2
# m2 *\m0  + m3  - σ_3/ + \m0  + m2  - σ_2/*\m2  + m3  - σ_1//*\2*σ_1*\m1  + m2
#
#
#       \   /    2     2      \ /  2     2      \\
#  - σ_3/ - \- m0  + m1  + σ_1/*\m2  - m3  + σ_1//

# %% [markdown]
# half angle (α+β-δ)
# $$
# \cos\frac{\theta}{2} = \sqrt{\frac{1+\cos\theta}{2}}
# $$
# should factorize

# %%
# factor(simplify(v + cosθhat12d_sq*cosθ23n_sq*cosζ221n_sq))
# Out:
#   16   8       16   6   2       16   6           16   4   4       16   4   2
# m0  *m2  - 4*m0  *m2 *m3  - 4*m0  *m2 *σ_1 + 6*m0  *m2 *m3  + 4*m0  *m2 *m3 *σ
#
#          16   4    2       16   2   6       16   2   4           16   2   2
# _1 + 6*m0  *m2 *σ_1  - 4*m0  *m2 *m3  + 4*m0  *m2 *m3 *σ_1 + 4*m0  *m2 *m3 *σ_
#
#  2       16   2    3     16   8       16   6           16   4    2       16
# 1  - 4*m0  *m2 *σ_1  + m0  *m3  - 4*m0  *m3 *σ_1 + 6*m0  *m3 *σ_1  - 4*m0  *m3
#
# 2    3     16    4       14   2   8        14   2   6   2        14   2   6
#  *σ_1  + m0  *σ_1  - 4*m0  *m1 *m2  + 16*m0  *m1 *m2 *m3  + 16*m0  *m1 *m2 *σ_
#
#          14   2   4   4        14   2   4   2            14   2   4    2
# 1 - 24*m0  *m1 *m2 *m3  - 16*m0  *m1 *m2 *m3 *σ_1 - 24*m0  *m1 *m2 *σ_1  + 16*
#
#   14   2   2   6        14   2   2   4            14   2   2   2    2        1
# m0  *m1 *m2 *m3  - 16*m0  *m1 *m2 *m3 *σ_1 - 16*m0  *m1 *m2 *m3 *σ_1  + 16*m0
#
# 4   2   2    3       14   2   8        14   2   6            14   2   4    2
#  *m1 *m2 *σ_1  - 4*m0  *m1 *m3  + 16*m0  *m1 *m3 *σ_1 - 24*m0  *m1 *m3 *σ_1  +
#
#       14   2   2    3       14   2    4       14   10        14   8   2
#  16*m0  *m1 *m3 *σ_1  - 4*m0  *m1 *σ_1  - 4*m0  *m2   + 16*m0  *m2 *m3  + 12*m
#
#  14   8           14   8            14   6   4        14   6   2           14
# 0  *m2 *σ_1 - 4*m0  *m2 *σ_2 - 24*m0  *m2 *m3  + 16*m0  *m2 *m3 *σ_2 - 8*m0  *
#
#   6    2        14   6                14   4   6        14   4   4
# m2 *σ_1  + 16*m0  *m2 *σ_1*σ_2 + 16*m0  *m2 *m3  - 40*m0  *m2 *m3 *σ_1 - 24*m0
#
# 14   4   4            14   4   2    2        14   4   2               14   4
#   *m2 *m3 *σ_2 - 32*m0  *m2 *m3 *σ_1  - 16*m0  *m2 *m3 *σ_1*σ_2 - 8*m0  *m2 *σ
#
#   3        14   4    2           14   2   8        14   2   6            14
# _1  - 24*m0  *m2 *σ_1 *σ_2 - 4*m0  *m2 *m3  + 32*m0  *m2 *m3 *σ_1 + 16*m0  *m2
#
# 2   6            14   2   4    2        14   2   4                14   2   2
#  *m3 *σ_2 - 40*m0  *m2 *m3 *σ_1  - 16*m0  *m2 *m3 *σ_1*σ_2 - 16*m0  *m2 *m3 *σ
#
#   2            14   2    4        14   2    3           14   8           14
# _1 *σ_2 + 12*m0  *m2 *σ_1  + 16*m0  *m2 *σ_1 *σ_2 - 4*m0  *m3 *σ_1 - 4*m0  *m3
#
# 8            14   6    2        14   6                14   4    3        14
#  *σ_2 + 16*m0  *m3 *σ_1  + 16*m0  *m3 *σ_1*σ_2 - 24*m0  *m3 *σ_1  - 24*m0  *m3
#
# 4    2            14   2    4        14   2    3           14    5       14
#  *σ_1 *σ_2 + 16*m0  *m3 *σ_1  + 16*m0  *m3 *σ_1 *σ_2 - 4*m0  *σ_1  - 4*m0  *σ_
#
#  4           12   4   8        12   4   6   2        12   4   6            12
# 1 *σ_2 + 6*m0  *m1 *m2  - 24*m0  *m1 *m2 *m3  - 24*m0  *m1 *m2 *σ_1 + 36*m0  *
#
#   4   4   4        12   4   4   2            12   4   4    2        12   4   2
# m1 *m2 *m3  + 24*m0  *m1 *m2 *m3 *σ_1 + 36*m0  *m1 *m2 *σ_1  - 24*m0  *m1 *m2
#
#    6        12   4   2   4            12   4   2   2    2        12   4   2
# *m3  + 24*m0  *m1 *m2 *m3 *σ_1 + 24*m0  *m1 *m2 *m3 *σ_1  - 24*m0  *m1 *m2 *σ_
#
#  3       12   4   8        12   4   6            12   4   4    2        12   4
# 1  + 6*m0  *m1 *m3  - 24*m0  *m1 *m3 *σ_1 + 36*m0  *m1 *m3 *σ_1  - 24*m0  *m1
#
#    2    3       12   4    4        12   2   10        12   2   8   2        12
# *m3 *σ_1  + 6*m0  *m1 *σ_1  + 16*m0  *m1 *m2   - 64*m0  *m1 *m2 *m3  - 60*m0
#
#    2   8            12   2   8            12   2   6   4        12   2   6   2
# *m1 *m2 *σ_1 + 16*m0  *m1 *m2 *σ_2 + 96*m0  *m1 *m2 *m3  + 48*m0  *m1 *m2 *m3
#
#             12   2   6   2            12   2   6    2        12   2   6
# *σ_1 - 64*m0  *m1 *m2 *m3 *σ_2 + 80*m0  *m1 *m2 *σ_1  - 64*m0  *m1 *m2 *σ_1*σ_
#
#          12   2   4   6        12   2   4   4            12   2   4   4
# 2 - 64*m0  *m1 *m2 *m3  + 88*m0  *m1 *m2 *m3 *σ_1 + 96*m0  *m1 *m2 *m3 *σ_2 +
#
#      12   2   4   2    2        12   2   4   2                12   2   4    3
# 80*m0  *m1 *m2 *m3 *σ_1  + 64*m0  *m1 *m2 *m3 *σ_1*σ_2 - 40*m0  *m1 *m2 *σ_1
#
#        12   2   4    2            12   2   2   8        12   2   2   6
# + 96*m0  *m1 *m2 *σ_1 *σ_2 + 16*m0  *m1 *m2 *m3  - 80*m0  *m1 *m2 *m3 *σ_1 - 6
#
#     12   2   2   6             12   2   2   4    2        12   2   2   4
# 4*m0  *m1 *m2 *m3 *σ_2 + 112*m0  *m1 *m2 *m3 *σ_1  + 64*m0  *m1 *m2 *m3 *σ_1*σ
#
#           12   2   2   2    3        12   2   2   2    2            12   2   2
# _2 - 48*m0  *m1 *m2 *m3 *σ_1  + 64*m0  *m1 *m2 *m3 *σ_1 *σ_2 - 64*m0  *m1 *m2
#
#     3           12   2   8            12   2   8            12   2   6    2
# *σ_1 *σ_2 + 4*m0  *m1 *m3 *σ_1 + 16*m0  *m1 *m3 *σ_2 - 16*m0  *m1 *m3 *σ_1  -
#
#      12   2   6                12   2   4    3        12   2   4    2
# 64*m0  *m1 *m3 *σ_1*σ_2 + 24*m0  *m1 *m3 *σ_1  + 96*m0  *m1 *m3 *σ_1 *σ_2 - 16
#
#    12   2   2    4        12   2   2    3           12   2    5        12   2
# *m0  *m1 *m3 *σ_1  - 64*m0  *m1 *m3 *σ_1 *σ_2 + 4*m0  *m1 *σ_1  + 16*m0  *m1 *
#
#    4           12   12        12   10   2       12   10           12   10
# σ_1 *σ_2 + 6*m0  *m2   - 24*m0  *m2  *m3  - 8*m0  *m2  *σ_1 + 4*m0  *m2  *σ_2
#
#        12   8   4        12   8   2            12   8   2            12   8
# + 36*m0  *m2 *m3  - 40*m0  *m2 *m3 *σ_1 - 16*m0  *m2 *m3 *σ_2 - 22*m0  *m2 *σ_
#
#  2       12   8    2        12   6   6         12   6   4            12   6
# 1  + 6*m0  *m2 *σ_2  - 24*m0  *m2 *m3  + 120*m0  *m2 *m3 *σ_1 + 24*m0  *m2 *m3
#
# 4            12   6   2    2        12   6   2                12   6   2    2
#  *σ_2 + 64*m0  *m2 *m3 *σ_1  - 48*m0  *m2 *m3 *σ_1*σ_2 - 24*m0  *m2 *m3 *σ_2
#
#        12   6    3        12   6    2            12   6        2       12   4
# + 48*m0  *m2 *σ_1  - 40*m0  *m2 *σ_1 *σ_2 - 24*m0  *m2 *σ_1*σ_2  + 6*m0  *m2 *
#
#   8        12   4   6            12   4   6             12   4   4    2
# m3  - 88*m0  *m2 *m3 *σ_1 - 16*m0  *m2 *m3 *σ_2 + 136*m0  *m2 *m3 *σ_1  + 112*
#
#   12   4   4                12   4   4    2        12   4   2    3        12
# m0  *m2 *m3 *σ_1*σ_2 + 36*m0  *m2 *m3 *σ_2  + 64*m0  *m2 *m3 *σ_1  + 80*m0  *m
#
#  4   2    2            12   4   2        2        12   4    4        12   4
# 2 *m3 *σ_1 *σ_2 + 24*m0  *m2 *m3 *σ_1*σ_2  - 22*m0  *m2 *σ_1  + 80*m0  *m2 *σ_
#
#  3            12   4    2    2        12   2   8           12   2   8
# 1 *σ_2 + 36*m0  *m2 *σ_1 *σ_2  + 16*m0  *m2 *m3 *σ_1 + 4*m0  *m2 *m3 *σ_2 - 88
#
#    12   2   6    2        12   2   6                12   2   6    2         12
# *m0  *m2 *m3 *σ_1  - 80*m0  *m2 *m3 *σ_1*σ_2 - 24*m0  *m2 *m3 *σ_2  + 120*m0
#
#    2   4    3        12   2   4    2            12   2   4        2        12
# *m2 *m3 *σ_1  + 88*m0  *m2 *m3 *σ_1 *σ_2 + 24*m0  *m2 *m3 *σ_1*σ_2  - 40*m0  *
#
#   2   2    4        12   2   2    3            12   2   2    2    2       12
# m2 *m3 *σ_1  + 48*m0  *m2 *m3 *σ_1 *σ_2 + 24*m0  *m2 *m3 *σ_1 *σ_2  - 8*m0  *m
#
#  2    5        12   2    4            12   2    3    2       12      4   _____
# 2 *σ_1  - 60*m0  *m2 *σ_1 *σ_2 - 24*m0  *m2 *σ_1 *σ_2  + 4*m0  *m2*m3 *\/ σ_1
#
#        12   8    2        12   8               12   8    2        12   6    3
#  + 6*m0  *m3 *σ_1  + 16*m0  *m3 *σ_1*σ_2 + 6*m0  *m3 *σ_2  - 24*m0  *m3 *σ_1
#
#        12   6    2            12   6        2        12   4    4        12   4
# - 64*m0  *m3 *σ_1 *σ_2 - 24*m0  *m3 *σ_1*σ_2  + 36*m0  *m3 *σ_1  + 96*m0  *m3
#
#     3            12   4    2    2        12   2    5        12   2    4
# *σ_1 *σ_2 + 36*m0  *m3 *σ_1 *σ_2  - 24*m0  *m3 *σ_1  - 64*m0  *m3 *σ_1 *σ_2 -
#
#      12   2    3    2       12    6        12    5           12    4    2
# 24*m0  *m3 *σ_1 *σ_2  + 6*m0  *σ_1  + 16*m0  *σ_1 *σ_2 + 6*m0  *σ_1 *σ_2  - 4*
#
#   11   3   4        11   2   4   _____       11      6       11      4
# m0  *m2 *m3  + 12*m0  *m2 *m3 *\/ σ_1  + 4*m0  *m2*m3  - 4*m0  *m2*m3 *σ_1 + 4
#
#    11   6   _____       11   4    3/2       10   6   8        10   6   6   2
# *m0  *m3 *\/ σ_1  - 4*m0  *m3 *σ_1    - 4*m0  *m1 *m2  + 16*m0  *m1 *m2 *m3  +
#
#       10   6   6            10   6   4   4        10   6   4   2            10
#  16*m0  *m1 *m2 *σ_1 - 24*m0  *m1 *m2 *m3  - 16*m0  *m1 *m2 *m3 *σ_1 - 24*m0
#
#    6   4    2        10   6   2   6        10   6   2   4            10   6
# *m1 *m2 *σ_1  + 16*m0  *m1 *m2 *m3  - 16*m0  *m1 *m2 *m3 *σ_1 - 16*m0  *m1 *m2
#
# 2   2    2        10   6   2    3       10   6   8        10   6   6
#  *m3 *σ_1  + 16*m0  *m1 *m2 *σ_1  - 4*m0  *m1 *m3  + 16*m0  *m1 *m3 *σ_1 - 24*
#
#   10   6   4    2        10   6   2    3       10   6    4        10   4   10
# m0  *m1 *m3 *σ_1  + 16*m0  *m1 *m3 *σ_1  - 4*m0  *m1 *σ_1  - 24*m0  *m1 *m2
#
#        10   4   8   2         10   4   8            10   4   8             10
# + 96*m0  *m1 *m2 *m3  + 100*m0  *m1 *m2 *σ_1 - 24*m0  *m1 *m2 *σ_2 - 144*m0  *
#
#   4   6   4         10   4   6   2            10   4   6   2             10
# m1 *m2 *m3  - 112*m0  *m1 *m2 *m3 *σ_1 + 96*m0  *m1 *m2 *m3 *σ_2 - 160*m0  *m1
#
# 4   6    2        10   4   6                10   4   4   6        10   4   4
#  *m2 *σ_1  + 96*m0  *m1 *m2 *σ_1*σ_2 + 96*m0  *m1 *m2 *m3  - 72*m0  *m1 *m2 *m
#
#  4             10   4   4   4            10   4   4   2    2        10   4   4
# 3 *σ_1 - 144*m0  *m1 *m2 *m3 *σ_2 - 80*m0  *m1 *m2 *m3 *σ_1  - 96*m0  *m1 *m2
#
#    2                 10   4   4    3         10   4   4    2            10   4
# *m3 *σ_1*σ_2 + 120*m0  *m1 *m2 *σ_1  - 144*m0  *m1 *m2 *σ_1 *σ_2 - 24*m0  *m1
#
#    2   8        10   4   2   6            10   4   2   6             10   4
# *m2 *m3  + 80*m0  *m1 *m2 *m3 *σ_1 + 96*m0  *m1 *m2 *m3 *σ_2 - 128*m0  *m1 *m2
#
# 2   4    2        10   4   2   4                 10   4   2   2    3        10
#  *m3 *σ_1  - 96*m0  *m1 *m2 *m3 *σ_1*σ_2 + 112*m0  *m1 *m2 *m3 *σ_1  - 96*m0
#
#    4   2   2    2            10   4   2    4        10   4   2    3
# *m1 *m2 *m3 *σ_1 *σ_2 - 40*m0  *m1 *m2 *σ_1  + 96*m0  *m1 *m2 *σ_1 *σ_2 + 4*m0
#
# 10   4   8            10   4   8            10   4   6    2        10   4   6
#   *m1 *m3 *σ_1 - 24*m0  *m1 *m3 *σ_2 - 16*m0  *m1 *m3 *σ_1  + 96*m0  *m1 *m3 *
#
#                10   4   4    3         10   4   4    2            10   4   2
# σ_1*σ_2 + 24*m0  *m1 *m3 *σ_1  - 144*m0  *m1 *m3 *σ_1 *σ_2 - 16*m0  *m1 *m3 *σ
#
#   4        10   4   2    3           10   4    5        10   4    4
# _1  + 96*m0  *m1 *m3 *σ_1 *σ_2 + 4*m0  *m1 *σ_1  - 24*m0  *m1 *σ_1 *σ_2 - 24*m
#
#  10   2   12        10   2   10   2        10   2   10            10   2   10
# 0  *m1 *m2   + 96*m0  *m1 *m2  *m3  + 80*m0  *m1 *m2  *σ_1 - 16*m0  *m1 *m2  *
#
#             10   2   8   4        10   2   8   2            10   2   8   2
# σ_2 - 144*m0  *m1 *m2 *m3  - 32*m0  *m1 *m2 *m3 *σ_1 + 64*m0  *m1 *m2 *m3 *σ_2
#
#         10   2   8    2        10   2   8                10   2   8    2
#  - 76*m0  *m1 *m2 *σ_1  + 48*m0  *m1 *m2 *σ_1*σ_2 - 24*m0  *m1 *m2 *σ_2  + 96*
#
#   10   2   6   6         10   2   6   4            10   2   6   4
# m0  *m1 *m2 *m3  - 192*m0  *m1 *m2 *m3 *σ_1 - 96*m0  *m1 *m2 *m3 *σ_2 - 176*m0
#
# 10   2   6   2    2        10   2   6   2    2        10   2   6    3        1
#   *m1 *m2 *m3 *σ_1  + 96*m0  *m1 *m2 *m3 *σ_2  - 16*m0  *m1 *m2 *σ_1  - 32*m0
#
# 0   2   6    2            10   2   6        2        10   2   4   8         10
#  *m1 *m2 *σ_1 *σ_2 + 96*m0  *m1 *m2 *σ_1*σ_2  - 24*m0  *m1 *m2 *m3  + 160*m0
#
#    2   4   6            10   2   4   6             10   2   4   4    2
# *m1 *m2 *m3 *σ_1 + 64*m0  *m1 *m2 *m3 *σ_2 - 184*m0  *m1 *m2 *m3 *σ_1  - 160*m
#
#  10   2   4   4                 10   2   4   4    2        10   2   4   2    3
# 0  *m1 *m2 *m3 *σ_1*σ_2 - 144*m0  *m1 *m2 *m3 *σ_2  + 48*m0  *m1 *m2 *m3 *σ_1
#
#          10   2   4   2    2            10   2   4   2        2        10   2
#  - 128*m0  *m1 *m2 *m3 *σ_1 *σ_2 - 96*m0  *m1 *m2 *m3 *σ_1*σ_2  + 64*m0  *m1 *
#
#   4    4        10   2   4    3             10   2   4    2    2       10   2
# m2 *σ_1  - 32*m0  *m1 *m2 *σ_1 *σ_2 - 144*m0  *m1 *m2 *σ_1 *σ_2  - 8*m0  *m1 *
#
#   3   2   _____        10   2   2   8            10   2   2   8            10
# m2 *m3 *\/ σ_1  - 16*m0  *m1 *m2 *m3 *σ_1 - 16*m0  *m1 *m2 *m3 *σ_2 + 48*m0  *
#
#   2   2   6    2         10   2   2   6                10   2   2   6    2
# m1 *m2 *m3 *σ_1  + 128*m0  *m1 *m2 *m3 *σ_1*σ_2 + 96*m0  *m1 *m2 *m3 *σ_2  - 8
#
#     10   2   2   4    3         10   2   2   4    2            10   2   2   4
# 0*m0  *m1 *m2 *m3 *σ_1  - 160*m0  *m1 *m2 *m3 *σ_1 *σ_2 - 96*m0  *m1 *m2 *m3 *
#
#        2        10   2   2   2    4        10   2   2   2    2    2        10
# σ_1*σ_2  + 80*m0  *m1 *m2 *m3 *σ_1  - 96*m0  *m1 *m2 *m3 *σ_1 *σ_2  - 32*m0  *
#
#   2   2    5        10   2   2    4            10   2   2    3    2       10
# m1 *m2 *σ_1  + 48*m0  *m1 *m2 *σ_1 *σ_2 + 96*m0  *m1 *m2 *σ_1 *σ_2  + 4*m0  *m
#
#  2      4   _____       10   2      2    3/2       10   2   8    2        10
# 1 *m2*m3 *\/ σ_1  + 8*m0  *m1 *m2*m3 *σ_1    + 4*m0  *m1 *m3 *σ_1  - 16*m0  *m
#
#  2   8                10   2   8    2        10   2   6    3        10   2   6
# 1 *m3 *σ_1*σ_2 - 24*m0  *m1 *m3 *σ_2  - 16*m0  *m1 *m3 *σ_1  + 64*m0  *m1 *m3
#
#     2            10   2   6        2        10   2   4    4        10   2   4
# *σ_1 *σ_2 + 96*m0  *m1 *m3 *σ_1*σ_2  + 24*m0  *m1 *m3 *σ_1  - 96*m0  *m1 *m3 *
#
#    3             10   2   4    2    2        10   2   2    5        10   2   2
# σ_1 *σ_2 - 144*m0  *m1 *m3 *σ_1 *σ_2  - 16*m0  *m1 *m3 *σ_1  + 64*m0  *m1 *m3
#
#     4            10   2   2    3    2       10   2    6        10   2    5
# *σ_1 *σ_2 + 96*m0  *m1 *m3 *σ_1 *σ_2  + 4*m0  *m1 *σ_1  - 16*m0  *m1 *σ_1 *σ_2
#
#         10   2    4    2       10   14        10   12   2       10   12
#  - 24*m0  *m1 *σ_1 *σ_2  - 4*m0  *m2   + 16*m0  *m2  *m3  - 8*m0  *m2  *σ_1 +
#
#     10   12            10   10   4        10   10   2            10   10   2
# 4*m0  *m2  *σ_2 - 24*m0  *m2  *m3  + 80*m0  *m2  *m3 *σ_1 - 16*m0  *m2  *m3 *σ
#
#           10   10    2        10   10               10   10    2        10   8
# _2 + 48*m0  *m2  *σ_1  - 32*m0  *m2  *σ_1*σ_2 + 4*m0  *m2  *σ_2  + 16*m0  *m2
#
#    6         10   8   4            10   8   4            10   8   2    2
# *m3  - 160*m0  *m2 *m3 *σ_1 + 24*m0  *m2 *m3 *σ_2 - 16*m0  *m2 *m3 *σ_1  + 80*
#
#   10   8   2                10   8   2    2        10   8    3        10   8
# m0  *m2 *m3 *σ_1*σ_2 - 16*m0  *m2 *m3 *σ_2  - 36*m0  *m2 *σ_1  + 64*m0  *m2 *σ
#
#   2            10   8        2       10   8    3       10   6   8         10
# _1 *σ_2 - 40*m0  *m2 *σ_1*σ_2  - 4*m0  *m2 *σ_2  - 4*m0  *m2 *m3  + 112*m0  *m
#
#  6   6            10   6   6             10   6   4    2        10   6   4
# 2 *m3 *σ_1 - 16*m0  *m2 *m3 *σ_2 - 264*m0  *m2 *m3 *σ_1  - 80*m0  *m2 *m3 *σ_1
#
#             10   6   4    2         10   6   2    3        10   6   2    2
# *σ_2 + 24*m0  *m2 *m3 *σ_2  - 160*m0  *m2 *m3 *σ_1  + 48*m0  *m2 *m3 *σ_1 *σ_2
#
#          10   6   2        2        10   6   2    3        10   6    4
#  + 112*m0  *m2 *m3 *σ_1*σ_2  + 16*m0  *m2 *m3 *σ_2  - 36*m0  *m2 *σ_1  - 16*m0
#
# 10   6    3             10   6    2    2        10   6        3        10   4
#   *m2 *σ_1 *σ_2 + 120*m0  *m2 *σ_1 *σ_2  + 16*m0  *m2 *σ_1*σ_2  - 24*m0  *m2 *
#
#   8           10   4   8             10   4   6    2        10   4   6
# m3 *σ_1 + 4*m0  *m2 *m3 *σ_2 + 192*m0  *m2 *m3 *σ_1  + 48*m0  *m2 *m3 *σ_1*σ_2
#
#         10   4   6    2         10   4   4    3         10   4   4    2
#  - 16*m0  *m2 *m3 *σ_2  - 264*m0  *m2 *m3 *σ_1  - 184*m0  *m2 *m3 *σ_1 *σ_2 -
#
#       10   4   4        2        10   4   4    3        10   4   2    4
# 128*m0  *m2 *m3 *σ_1*σ_2  - 24*m0  *m2 *m3 *σ_2  - 16*m0  *m2 *m3 *σ_1  - 176*
#
#   10   4   2    3            10   4   2    2    2        10   4   2        3
# m0  *m2 *m3 *σ_1 *σ_2 - 80*m0  *m2 *m3 *σ_1 *σ_2  - 16*m0  *m2 *m3 *σ_1*σ_2  +
#
#       10   4    5        10   4    4             10   4    3    2        10
#  48*m0  *m2 *σ_1  - 76*m0  *m2 *σ_1 *σ_2 - 160*m0  *m2 *σ_1 *σ_2  - 24*m0  *m2
#
# 4    2    3       10   3   4   _____       10   3   2   _____            10
#  *σ_1 *σ_2  + 4*m0  *m2 *m3 *\/ σ_1  + 8*m0  *m2 *m3 *\/ σ_1 *σ_2 - 24*m0  *m2
#
# 2   8    2        10   2   8               10   2   8    2         10   2   6
#  *m3 *σ_1  - 16*m0  *m2 *m3 *σ_1*σ_2 + 4*m0  *m2 *m3 *σ_2  + 112*m0  *m2 *m3 *
#
#    3         10   2   6    2            10   2   6        2        10   2   6
# σ_1  + 160*m0  *m2 *m3 *σ_1 *σ_2 + 80*m0  *m2 *m3 *σ_1*σ_2  + 16*m0  *m2 *m3 *
#
#    3         10   2   4    4         10   2   4    3            10   2   4
# σ_2  - 160*m0  *m2 *m3 *σ_1  - 192*m0  *m2 *m3 *σ_1 *σ_2 - 72*m0  *m2 *m3 *σ_1
#
# 2    2        10   2   4        3        10   2   2    5        10   2   2
#  *σ_2  - 16*m0  *m2 *m3 *σ_1*σ_2  + 80*m0  *m2 *m3 *σ_1  - 32*m0  *m2 *m3 *σ_1
#
# 4             10   2   2    3    2        10   2   2    2    3       10   2
#  *σ_2 - 112*m0  *m2 *m3 *σ_1 *σ_2  - 16*m0  *m2 *m3 *σ_1 *σ_2  - 8*m0  *m2 *σ_
#
#  6        10   2    5             10   2    4    2        10   2    3    3
# 1  + 80*m0  *m2 *σ_1 *σ_2 + 100*m0  *m2 *σ_1 *σ_2  + 16*m0  *m2 *σ_1 *σ_2  + 8
#
#    10      6   _____        10      4    3/2        10      4   _____
# *m0  *m2*m3 *\/ σ_1  - 12*m0  *m2*m3 *σ_1    - 12*m0  *m2*m3 *\/ σ_1 *σ_2 - 8*
#
#   10      4   _____           10      2    3/2           10   8    3        10
# m0  *m2*m3 *\/ σ_1 *σ_3 - 8*m0  *m2*m3 *σ_1   *σ_2 - 4*m0  *m3 *σ_1  - 24*m0
#
#    8    2            10   8        2       10   8    3        10   6    4
# *m3 *σ_1 *σ_2 - 24*m0  *m3 *σ_1*σ_2  - 4*m0  *m3 *σ_2  + 16*m0  *m3 *σ_1  + 96
#
#    10   6    3            10   6    2    2        10   6        3        10
# *m0  *m3 *σ_1 *σ_2 + 96*m0  *m3 *σ_1 *σ_2  + 16*m0  *m3 *σ_1*σ_2  - 24*m0  *m3
#
# 4    5         10   4    4             10   4    3    2        10   4    2
#  *σ_1  - 144*m0  *m3 *σ_1 *σ_2 - 144*m0  *m3 *σ_1 *σ_2  - 24*m0  *m3 *σ_1 *σ_2
#
# 3        10   2    6        10   2    5            10   2    4    2        10
#   + 16*m0  *m3 *σ_1  + 96*m0  *m3 *σ_1 *σ_2 + 96*m0  *m3 *σ_1 *σ_2  + 16*m0  *
#
#   2    3    3       10    7        10    6            10    5    2       10
# m3 *σ_1 *σ_2  - 4*m0  *σ_1  - 24*m0  *σ_1 *σ_2 - 24*m0  *σ_1 *σ_2  - 4*m0  *σ_
#
#  4    3       9   2   5   2        9   2   4   2   _____       9   2   3   4
# 1 *σ_2  + 8*m0 *m1 *m2 *m3  - 24*m0 *m1 *m2 *m3 *\/ σ_1  + 4*m0 *m1 *m2 *m3  -
#
#       9   2   2   4   _____        9   2   2   2    3/2        9   2      6
#  32*m0 *m1 *m2 *m3 *\/ σ_1  + 32*m0 *m1 *m2 *m3 *σ_1    - 12*m0 *m1 *m2*m3  +
#
#      9   2      4           9   2      2    2       9   2   6   _____        9
# 12*m0 *m1 *m2*m3 *σ_1 - 8*m0 *m1 *m2*m3 *σ_1  - 8*m0 *m1 *m3 *\/ σ_1  + 16*m0
#
#    2   4    3/2       9   2   2    5/2       9   5   4       9   5   2
# *m1 *m3 *σ_1    - 8*m0 *m1 *m3 *σ_1    + 8*m0 *m2 *m3  - 8*m0 *m2 *m3 *σ_2 - 2
#
#     9   4   4   _____        9   4   2   _____            9   3   6        9
# 0*m0 *m2 *m3 *\/ σ_1  + 24*m0 *m2 *m3 *\/ σ_1 *σ_2 - 16*m0 *m2 *m3  + 12*m0 *m
#
#  3   4            9   3   4            9   2   6   _____        9   2   4    3
# 2 *m3 *σ_1 + 16*m0 *m2 *m3 *σ_2 + 28*m0 *m2 *m3 *\/ σ_1  - 20*m0 *m2 *m3 *σ_1
#
# /2        9   2   4   _____           9   2   4   _____            9   2   2
#    - 20*m0 *m2 *m3 *\/ σ_1 *σ_2 - 8*m0 *m2 *m3 *\/ σ_1 *σ_3 - 32*m0 *m2 *m3 *σ
#
#   3/2           9      8        9      6           9      6            9
# _1   *σ_2 + 8*m0 *m2*m3  - 20*m0 *m2*m3 *σ_1 - 8*m0 *m2*m3 *σ_2 + 12*m0 *m2*m3
#
# 4    2       9      4               9      2    2           9   8   _____
#  *σ_1  + 8*m0 *m2*m3 *σ_1*σ_3 + 8*m0 *m2*m3 *σ_1 *σ_2 + 8*m0 *m3 *\/ σ_1  - 16
#
#    9   6    3/2        9   6   _____           9   4    5/2       9   4    3/2
# *m0 *m3 *σ_1    - 12*m0 *m3 *\/ σ_1 *σ_2 + 8*m0 *m3 *σ_1    + 4*m0 *m3 *σ_1
#
#            9   2    5/2         8   8   8       8   8   6   2       8   8   6
# *σ_2 + 8*m0 *m3 *σ_1   *σ_2 + m0 *m1 *m2  - 4*m0 *m1 *m2 *m3  - 4*m0 *m1 *m2 *
#
#           8   8   4   4       8   8   4   2           8   8   4    2       8
# σ_1 + 6*m0 *m1 *m2 *m3  + 4*m0 *m1 *m2 *m3 *σ_1 + 6*m0 *m1 *m2 *σ_1  - 4*m0 *m
#
#  8   2   6       8   8   2   4           8   8   2   2    2       8   8   2
# 1 *m2 *m3  + 4*m0 *m1 *m2 *m3 *σ_1 + 4*m0 *m1 *m2 *m3 *σ_1  - 4*m0 *m1 *m2 *σ_
#
#  3     8   8   8       8   8   6           8   8   4    2       8   8   2    3
# 1  + m0 *m1 *m3  - 4*m0 *m1 *m3 *σ_1 + 6*m0 *m1 *m3 *σ_1  - 4*m0 *m1 *m3 *σ_1
#
#      8   8    4        8   6   10        8   6   8   2        8   6   8
#  + m0 *m1 *σ_1  + 16*m0 *m1 *m2   - 64*m0 *m1 *m2 *m3  - 68*m0 *m1 *m2 *σ_1 +
#
#      8   6   8            8   6   6   4        8   6   6   2            8   6
# 16*m0 *m1 *m2 *σ_2 + 96*m0 *m1 *m2 *m3  + 80*m0 *m1 *m2 *m3 *σ_1 - 64*m0 *m1 *
#
#   6   2             8   6   6    2        8   6   6                8   6   4
# m2 *m3 *σ_2 + 112*m0 *m1 *m2 *σ_1  - 64*m0 *m1 *m2 *σ_1*σ_2 - 64*m0 *m1 *m2 *m
#
#  6        8   6   4   4            8   6   4   4            8   6   4   2    2
# 3  + 40*m0 *m1 *m2 *m3 *σ_1 + 96*m0 *m1 *m2 *m3 *σ_2 + 48*m0 *m1 *m2 *m3 *σ_1
#
#         8   6   4   2                8   6   4    3        8   6   4    2
#  + 64*m0 *m1 *m2 *m3 *σ_1*σ_2 - 88*m0 *m1 *m2 *σ_1  + 96*m0 *m1 *m2 *σ_1 *σ_2
#
#        8   6   2   8        8   6   2   6            8   6   2   6
# + 16*m0 *m1 *m2 *m3  - 48*m0 *m1 *m2 *m3 *σ_1 - 64*m0 *m1 *m2 *m3 *σ_2 + 80*m0
#
# 8   6   2   4    2        8   6   2   4                8   6   2   2    3
#  *m1 *m2 *m3 *σ_1  + 64*m0 *m1 *m2 *m3 *σ_1*σ_2 - 80*m0 *m1 *m2 *m3 *σ_1  + 64
#
#    8   6   2   2    2            8   6   2    4        8   6   2    3
# *m0 *m1 *m2 *m3 *σ_1 *σ_2 + 32*m0 *m1 *m2 *σ_1  - 64*m0 *m1 *m2 *σ_1 *σ_2 - 4*
#
#   8   6   8            8   6   8            8   6   6    2        8   6   6
# m0 *m1 *m3 *σ_1 + 16*m0 *m1 *m3 *σ_2 + 16*m0 *m1 *m3 *σ_1  - 64*m0 *m1 *m3 *σ_
#
#              8   6   4    3        8   6   4    2            8   6   2    4
# 1*σ_2 - 24*m0 *m1 *m3 *σ_1  + 96*m0 *m1 *m3 *σ_1 *σ_2 + 16*m0 *m1 *m3 *σ_1  -
#
#      8   6   2    3           8   6    5        8   6    4            8   4
# 64*m0 *m1 *m3 *σ_1 *σ_2 - 4*m0 *m1 *σ_1  + 16*m0 *m1 *σ_1 *σ_2 + 36*m0 *m1 *m2
#
# 12         8   4   10   2         8   4   10            8   4   10
#    - 144*m0 *m1 *m2  *m3  - 160*m0 *m1 *m2  *σ_1 + 24*m0 *m1 *m2  *σ_2 + 216*m
#
#  8   4   8   4         8   4   8   2            8   4   8   2             8
# 0 *m1 *m2 *m3  + 208*m0 *m1 *m2 *m3 *σ_1 - 96*m0 *m1 *m2 *m3 *σ_2 + 286*m0 *m1
#
# 4   8    2         8   4   8                8   4   8    2         8   4   6
#  *m2 *σ_1  - 112*m0 *m1 *m2 *σ_1*σ_2 + 36*m0 *m1 *m2 *σ_2  - 144*m0 *m1 *m2 *m
#
#  6        8   4   6   4             8   4   6   4            8   4   6   2
# 3  + 48*m0 *m1 *m2 *m3 *σ_1 + 144*m0 *m1 *m2 *m3 *σ_2 + 56*m0 *m1 *m2 *m3 *σ_1
#
# 2         8   4   6   2                 8   4   6   2    2         8   4   6
#   + 160*m0 *m1 *m2 *m3 *σ_1*σ_2 - 144*m0 *m1 *m2 *m3 *σ_2  - 264*m0 *m1 *m2 *σ
#
#   3         8   4   6    2             8   4   6        2       8   4   5   __
# _1  + 208*m0 *m1 *m2 *σ_1 *σ_2 - 144*m0 *m1 *m2 *σ_1*σ_2  + 4*m0 *m1 *m2 *\/ σ
#
# ___        8   4   4   8        8   4   4   6            8   4   4   6
# _1  + 36*m0 *m1 *m2 *m3  - 80*m0 *m1 *m2 *m3 *σ_1 - 96*m0 *m1 *m2 *m3 *σ_2 + 1
#
#      8   4   4   4    2         8   4   4   4    2         8   4   4   2    3
# 88*m0 *m1 *m2 *m3 *σ_1  + 216*m0 *m1 *m2 *m3 *σ_2  - 184*m0 *m1 *m2 *m3 *σ_1
#
#        8   4   4   2    2             8   4   4   2        2         8   4   4
# + 32*m0 *m1 *m2 *m3 *σ_1 *σ_2 + 144*m0 *m1 *m2 *m3 *σ_1*σ_2  + 136*m0 *m1 *m2
#
#     4         8   4   4    3             8   4   4    2    2       8   4   3
# *σ_1  - 192*m0 *m1 *m2 *σ_1 *σ_2 + 216*m0 *m1 *m2 *σ_1 *σ_2  - 8*m0 *m1 *m2 *m
#
#  2   _____       8   4   3    3/2        8   4   2   8            8   4   2
# 3 *\/ σ_1  - 8*m0 *m1 *m2 *σ_1    - 16*m0 *m1 *m2 *m3 *σ_1 + 24*m0 *m1 *m2 *m3
#
# 8            8   4   2   6    2        8   4   2   6                 8   4   2
#  *σ_2 + 40*m0 *m1 *m2 *m3 *σ_1  - 32*m0 *m1 *m2 *m3 *σ_1*σ_2 - 144*m0 *m1 *m2
#
#    6    2        8   4   2   4    3        8   4   2   4    2             8
# *m3 *σ_2  - 72*m0 *m1 *m2 *m3 *σ_1  + 80*m0 *m1 *m2 *m3 *σ_1 *σ_2 + 144*m0 *m1
#
# 4   2   4        2        8   4   2   2    4         8   4   2   2    3
#  *m2 *m3 *σ_1*σ_2  + 88*m0 *m1 *m2 *m3 *σ_1  - 160*m0 *m1 *m2 *m3 *σ_1 *σ_2 +
#
#       8   4   2   2    2    2        8   4   2    5        8   4   2    4
# 144*m0 *m1 *m2 *m3 *σ_1 *σ_2  - 40*m0 *m1 *m2 *σ_1  + 88*m0 *m1 *m2 *σ_1 *σ_2
#
#         8   4   2    3    2        8   4      4   _____        8   4      2
# - 144*m0 *m1 *m2 *σ_1 *σ_2  - 20*m0 *m1 *m2*m3 *\/ σ_1  + 16*m0 *m1 *m2*m3 *σ_
#
#  3/2       8   4       5/2       8   4   8    2        8   4   8
# 1    + 4*m0 *m1 *m2*σ_1    + 6*m0 *m1 *m3 *σ_1  - 16*m0 *m1 *m3 *σ_1*σ_2 + 36*
#
#   8   4   8    2        8   4   6    3        8   4   6    2             8   4
# m0 *m1 *m3 *σ_2  - 24*m0 *m1 *m3 *σ_1  + 64*m0 *m1 *m3 *σ_1 *σ_2 - 144*m0 *m1
#
#    6        2        8   4   4    4        8   4   4    3             8   4
# *m3 *σ_1*σ_2  + 36*m0 *m1 *m3 *σ_1  - 96*m0 *m1 *m3 *σ_1 *σ_2 + 216*m0 *m1 *m3
#
# 4    2    2        8   4   2    5        8   4   2    4             8   4   2
#  *σ_1 *σ_2  - 24*m0 *m1 *m3 *σ_1  + 64*m0 *m1 *m3 *σ_1 *σ_2 - 144*m0 *m1 *m3 *
#
#    3    2       8   4    6        8   4    5            8   4    4    2
# σ_1 *σ_2  + 6*m0 *m1 *σ_1  - 16*m0 *m1 *σ_1 *σ_2 + 36*m0 *m1 *σ_1 *σ_2  + 16*m
#
#  8   2   14        8   2   12   2        8   2   12            8   2   12
# 0 *m1 *m2   - 64*m0 *m1 *m2  *m3  - 40*m0 *m1 *m2  *σ_1 - 16*m0 *m1 *m2  *σ_2
#
#        8   2   10   4        8   2   10   2            8   2   10   2
# + 96*m0 *m1 *m2  *m3  - 32*m0 *m1 *m2  *m3 *σ_1 + 64*m0 *m1 *m2  *m3 *σ_2 - 16
#
#    8   2   10    2        8   2   10                8   2   10    2        8
# *m0 *m1 *m2  *σ_1  + 80*m0 *m1 *m2  *σ_1*σ_2 - 16*m0 *m1 *m2  *σ_2  - 64*m0 *m
#
#  2   8   6         8   2   8   4            8   2   8   4             8   2
# 1 *m2 *m3  + 208*m0 *m1 *m2 *m3 *σ_1 - 96*m0 *m1 *m2 *m3 *σ_2 + 224*m0 *m1 *m2
#
# 8   2    2         8   2   8   2                8   2   8   2    2         8
#  *m3 *σ_1  - 128*m0 *m1 *m2 *m3 *σ_1*σ_2 + 64*m0 *m1 *m2 *m3 *σ_2  + 140*m0 *m
#
#  2   8    3         8   2   8    2            8   2   8        2        8   2
# 1 *m2 *σ_1  - 176*m0 *m1 *m2 *σ_1 *σ_2 + 88*m0 *m1 *m2 *σ_1*σ_2  + 16*m0 *m1 *
#
#   8    3        8   2   6   8         8   2   6   6            8   2   6   6
# m2 *σ_2  + 16*m0 *m1 *m2 *m3  - 160*m0 *m1 *m2 *m3 *σ_1 + 64*m0 *m1 *m2 *m3 *σ
#
#           8   2   6   4    2        8   2   6   4                8   2   6   4
# _2 + 96*m0 *m1 *m2 *m3 *σ_1  + 32*m0 *m1 *m2 *m3 *σ_1*σ_2 - 96*m0 *m1 *m2 *m3
#
#     2        8   2   6   2    3        8   2   6   2    2             8   2
# *σ_2  - 16*m0 *m1 *m2 *m3 *σ_1  + 64*m0 *m1 *m2 *m3 *σ_1 *σ_2 - 160*m0 *m1 *m2
#
# 6   2        2        8   2   6   2    3         8   2   6    4         8   2
#  *m3 *σ_1*σ_2  - 64*m0 *m1 *m2 *m3 *σ_2  - 160*m0 *m1 *m2 *σ_1  + 224*m0 *m1 *
#
#   6    3             8   2   6    2    2        8   2   6        3       8   2
# m2 *σ_1 *σ_2 - 192*m0 *m1 *m2 *σ_1 *σ_2  - 64*m0 *m1 *m2 *σ_1*σ_2  - 8*m0 *m1
#
#    5   2   _____       8   2   5   _____            8   2   4   8            8
# *m2 *m3 *\/ σ_1  - 8*m0 *m1 *m2 *\/ σ_1 *σ_2 + 24*m0 *m1 *m2 *m3 *σ_1 - 16*m0
#
#    2   4   8            8   2   4   6    2        8   2   4   6    2        8
# *m1 *m2 *m3 *σ_2 - 32*m0 *m1 *m2 *m3 *σ_1  + 64*m0 *m1 *m2 *m3 *σ_2  + 56*m0 *
#
#   2   4   4    3         8   2   4   4    2            8   2   4   4        2
# m1 *m2 *m3 *σ_1  - 128*m0 *m1 *m2 *m3 *σ_1 *σ_2 + 80*m0 *m1 *m2 *m3 *σ_1*σ_2
#
#        8   2   4   4    3         8   2   4   2    4        8   2   4   2    3
# + 96*m0 *m1 *m2 *m3 *σ_2  - 176*m0 *m1 *m2 *m3 *σ_1  + 64*m0 *m1 *m2 *m3 *σ_1
#
#             8   2   4   2    2    2        8   2   4   2        3        8   2
# *σ_2 + 32*m0 *m1 *m2 *m3 *σ_1 *σ_2  + 64*m0 *m1 *m2 *m3 *σ_1*σ_2  + 64*m0 *m1
#
#    4    5         8   2   4    4             8   2   4    3    2        8   2
# *m2 *σ_1  - 176*m0 *m1 *m2 *σ_1 *σ_2 + 208*m0 *m1 *m2 *σ_1 *σ_2  + 96*m0 *m1 *
#
#   4    2    3        8   2   3   4   _____        8   2   3   2    3/2
# m2 *σ_1 *σ_2  - 52*m0 *m1 *m2 *m3 *\/ σ_1  + 24*m0 *m1 *m2 *m3 *σ_1    + 24*m0
#
# 8   2   3   2   _____            8   2   3   2   _____            8   2   3
#  *m1 *m2 *m3 *\/ σ_1 *σ_2 + 16*m0 *m1 *m2 *m3 *\/ σ_1 *σ_3 + 16*m0 *m1 *m2 *σ_
#
#  3/2            8   2   2   8    2        8   2   2   8                8   2
# 1   *σ_2 - 16*m0 *m1 *m2 *m3 *σ_1  + 16*m0 *m1 *m2 *m3 *σ_1*σ_2 - 16*m0 *m1 *m
#
#  2   8    2        8   2   2   6    3        8   2   2   6        2        8
# 2 *m3 *σ_2  + 80*m0 *m1 *m2 *m3 *σ_1  - 32*m0 *m1 *m2 *m3 *σ_1*σ_2  - 64*m0 *m
#
#  2   2   6    3         8   2   2   4    4        8   2   2   4    3
# 1 *m2 *m3 *σ_2  - 112*m0 *m1 *m2 *m3 *σ_1  + 32*m0 *m1 *m2 *m3 *σ_1 *σ_2 + 64*
#
#   8   2   2   4        3        8   2   2   2    5         8   2   2   2    4
# m0 *m1 *m2 *m3 *σ_1*σ_2  + 48*m0 *m1 *m2 *m3 *σ_1  - 128*m0 *m1 *m2 *m3 *σ_1 *
#
#             8   2   2   2    3    2        8   2   2   2    2    3        8
# σ_2 + 160*m0 *m1 *m2 *m3 *σ_1 *σ_2  + 64*m0 *m1 *m2 *m3 *σ_1 *σ_2  + 80*m0 *m1
#
# 2   2    5             8   2   2    4    2        8   2   2    3    3        8
#  *m2 *σ_1 *σ_2 - 112*m0 *m1 *m2 *σ_1 *σ_2  - 64*m0 *m1 *m2 *σ_1 *σ_2  + 16*m0
#
#    2      6   _____       8   2      4   _____            8   2      4   _____
# *m1 *m2*m3 *\/ σ_1  - 4*m0 *m1 *m2*m3 *\/ σ_1 *σ_2 + 16*m0 *m1 *m2*m3 *\/ σ_1
#
#             8   2      2    5/2        8   2      2    3/2            8   2
# *σ_3 - 16*m0 *m1 *m2*m3 *σ_1    - 40*m0 *m1 *m2*m3 *σ_1   *σ_2 - 16*m0 *m1 *m2
#
#    2    3/2           8   2       5/2           8   2   8    3        8   2
# *m3 *σ_1   *σ_3 - 8*m0 *m1 *m2*σ_1   *σ_2 - 4*m0 *m1 *m3 *σ_1  - 16*m0 *m1 *m3
#
# 8    2            8   2   8        2        8   2   8    3        8   2   6
#  *σ_1 *σ_2 + 24*m0 *m1 *m3 *σ_1*σ_2  + 16*m0 *m1 *m3 *σ_2  + 16*m0 *m1 *m3 *σ_
#
#  4        8   2   6    3            8   2   6    2    2        8   2   6
# 1  + 64*m0 *m1 *m3 *σ_1 *σ_2 - 96*m0 *m1 *m3 *σ_1 *σ_2  - 64*m0 *m1 *m3 *σ_1*σ
#
#   3        8   2   4    5        8   2   4    4             8   2   4    3
# _2  - 24*m0 *m1 *m3 *σ_1  - 96*m0 *m1 *m3 *σ_1 *σ_2 + 144*m0 *m1 *m3 *σ_1 *σ_2
#
# 2        8   2   4    2    3        8   2   2    6        8   2   2    5
#   + 96*m0 *m1 *m3 *σ_1 *σ_2  + 16*m0 *m1 *m3 *σ_1  + 64*m0 *m1 *m3 *σ_1 *σ_2 -
#
#       8   2   2    4    2        8   2   2    3    3       8   2    7        8
#  96*m0 *m1 *m3 *σ_1 *σ_2  - 64*m0 *m1 *m3 *σ_1 *σ_2  - 4*m0 *m1 *σ_1  - 16*m0
#
#    2    6            8   2    5    2        8   2    4    3     8   16       8
# *m1 *σ_1 *σ_2 + 24*m0 *m1 *σ_1 *σ_2  + 16*m0 *m1 *σ_1 *σ_2  + m0 *m2   - 4*m0
#
#    14   2        8   14           8   14           8   12   4        8   12
# *m2  *m3  + 12*m0 *m2  *σ_1 - 4*m0 *m2  *σ_2 + 6*m0 *m2  *m3  - 60*m0 *m2  *m3
#
# 2            8   12   2            8   12    2       8   12    2       8   10
#  *σ_1 + 16*m0 *m2  *m3 *σ_2 - 22*m0 *m2  *σ_1  + 6*m0 *m2  *σ_2  - 4*m0 *m2  *
#
#   6         8   10   4            8   10   4            8   10   2    2
# m3  + 100*m0 *m2  *m3 *σ_1 - 24*m0 *m2  *m3 *σ_2 - 76*m0 *m2  *m3 *σ_1  + 48*m
#
#  8   10   2                8   10   2    2        8   10    3        8   10
# 0 *m2  *m3 *σ_1*σ_2 - 24*m0 *m2  *m3 *σ_2  - 36*m0 *m2  *σ_1  + 64*m0 *m2  *σ_
#
#  2            8   10        2       8   10    3     8   8   8        8   8   6
# 1 *σ_2 - 40*m0 *m2  *σ_1*σ_2  - 4*m0 *m2  *σ_2  + m0 *m2 *m3  - 68*m0 *m2 *m3
#
#             8   8   6             8   8   4    2         8   8   4
# *σ_1 + 16*m0 *m2 *m3 *σ_2 + 286*m0 *m2 *m3 *σ_1  - 112*m0 *m2 *m3 *σ_1*σ_2 + 3
#
#     8   8   4    2         8   8   2    3         8   8   2    2            8
# 6*m0 *m2 *m3 *σ_2  + 140*m0 *m2 *m3 *σ_1  - 176*m0 *m2 *m3 *σ_1 *σ_2 + 88*m0 *
#
#   8   2        2        8   8   2    3        8   8    4         8   8    3
# m2 *m3 *σ_1*σ_2  + 16*m0 *m2 *m3 *σ_2  + 90*m0 *m2 *σ_1  - 160*m0 *m2 *σ_1 *σ_
#
#           8   8    2    2        8   8        3     8   8    4        8   6
# 2 + 136*m0 *m2 *σ_1 *σ_2  + 32*m0 *m2 *σ_1*σ_2  + m0 *m2 *σ_2  + 16*m0 *m2 *m3
#
# 8           8   6   8             8   6   6    2        8   6   6
#  *σ_1 - 4*m0 *m2 *m3 *σ_2 - 208*m0 *m2 *m3 *σ_1  + 80*m0 *m2 *m3 *σ_1*σ_2 - 24
#
#    8   6   6    2         8   6   4    3        8   6   4    2            8
# *m0 *m2 *m3 *σ_2  + 336*m0 *m2 *m3 *σ_1  + 56*m0 *m2 *m3 *σ_1 *σ_2 - 72*m0 *m2
#
# 6   4        2        8   6   4    3         8   6   2    4        8   6   2
#  *m3 *σ_1*σ_2  - 24*m0 *m2 *m3 *σ_2  + 140*m0 *m2 *m3 *σ_1  - 16*m0 *m2 *m3 *σ
#
#   3             8   6   2    2    2        8   6   2        3       8   6   2
# _1 *σ_2 - 184*m0 *m2 *m3 *σ_1 *σ_2  - 80*m0 *m2 *m3 *σ_1*σ_2  - 4*m0 *m2 *m3 *
#
#    4        8   6    5         8   6    4             8   6    3    2        8
# σ_2  - 36*m0 *m2 *σ_1  + 140*m0 *m2 *σ_1 *σ_2 - 264*m0 *m2 *σ_1 *σ_2  - 88*m0
#
#    6    2    3       8   6        4        8   5   4   _____        8   5   2
# *m2 *σ_1 *σ_2  - 4*m0 *m2 *σ_1*σ_2  - 20*m0 *m2 *m3 *\/ σ_1  + 16*m0 *m2 *m3 *
#
#   _____           8   5   _____    2        8   4   8    2        8   4   8
# \/ σ_1 *σ_2 + 4*m0 *m2 *\/ σ_1 *σ_2  + 36*m0 *m2 *m3 *σ_1  - 16*m0 *m2 *m3 *σ_
#
#             8   4   8    2         8   4   6    3        8   4   6    2
# 1*σ_2 + 6*m0 *m2 *m3 *σ_2  - 208*m0 *m2 *m3 *σ_1  - 32*m0 *m2 *m3 *σ_1 *σ_2 +
#
#      8   4   6        2        8   4   6    3         8   4   4    4        8
# 40*m0 *m2 *m3 *σ_1*σ_2  + 16*m0 *m2 *m3 *σ_2  + 286*m0 *m2 *m3 *σ_1  + 96*m0 *
#
#   4   4    3             8   4   4    2    2        8   4   4        3       8
# m2 *m3 *σ_1 *σ_2 + 188*m0 *m2 *m3 *σ_1 *σ_2  + 80*m0 *m2 *m3 *σ_1*σ_2  + 6*m0
#
#    4   4    4        8   4   2    5         8   4   2    4            8   4
# *m2 *m3 *σ_2  - 76*m0 *m2 *m3 *σ_1  + 224*m0 *m2 *m3 *σ_1 *σ_2 + 56*m0 *m2 *m3
#
# 2    3    2        8   4   2    2    3       8   4   2        4        8   4
#  *σ_1 *σ_2  + 48*m0 *m2 *m3 *σ_1 *σ_2  + 4*m0 *m2 *m3 *σ_1*σ_2  - 22*m0 *m2 *σ
#
#   6        8   4    5             8   4    4    2         8   4    3    3
# _1  - 16*m0 *m2 *σ_1 *σ_2 + 286*m0 *m2 *σ_1 *σ_2  + 112*m0 *m2 *σ_1 *σ_2  + 6*
#
#   8   4    2    4       8   4        8   3   6   _____       8   3   4    3/2
# m0 *m2 *σ_1 *σ_2  + 3*m0 *m2  + 16*m0 *m2 *m3 *\/ σ_1  - 4*m0 *m2 *m3 *σ_1
#
#        8   3   4   _____            8   3   2    3/2            8   3   2   __
# + 16*m0 *m2 *m3 *\/ σ_1 *σ_3 - 40*m0 *m2 *m3 *σ_1   *σ_2 - 16*m0 *m2 *m3 *\/ σ
#
# ___    2        8   3   2   _____               8   3    3/2    2        8   2
# _1 *σ_2  - 16*m0 *m2 *m3 *\/ σ_1 *σ_2*σ_3 - 8*m0 *m2 *σ_1   *σ_2  + 16*m0 *m2
#
#    8    3        8   2   8    2            8   2   8        2       8   2   8
# *m3 *σ_1  + 24*m0 *m2 *m3 *σ_1 *σ_2 - 16*m0 *m2 *m3 *σ_1*σ_2  - 4*m0 *m2 *m3 *
#
#    3        8   2   6    4         8   2   6    3            8   2   6    2
# σ_2  - 68*m0 *m2 *m3 *σ_1  - 160*m0 *m2 *m3 *σ_1 *σ_2 - 80*m0 *m2 *m3 *σ_1 *σ_
#
#  2        8   2   6        3       8   2   6    4         8   2   4    5
# 2  - 48*m0 *m2 *m3 *σ_1*σ_2  - 4*m0 *m2 *m3 *σ_2  + 100*m0 *m2 *m3 *σ_1  + 208
#
#    8   2   4    4            8   2   4    3    2        8   2   4    2    3
# *m0 *m2 *m3 *σ_1 *σ_2 + 48*m0 *m2 *m3 *σ_1 *σ_2  + 40*m0 *m2 *m3 *σ_1 *σ_2  +
#
#     8   2   4        4        8   2   2    6        8   2   2    5
# 4*m0 *m2 *m3 *σ_1*σ_2  - 60*m0 *m2 *m3 *σ_1  - 32*m0 *m2 *m3 *σ_1 *σ_2 + 208*m
#
#  8   2   2    4    2        8   2   2    3    3       8   2   2    2    4
# 0 *m2 *m3 *σ_1 *σ_2  + 80*m0 *m2 *m3 *σ_1 *σ_2  + 4*m0 *m2 *m3 *σ_1 *σ_2  - 2*
#
#   8   2   2        8   2    7        8   2    6             8   2    5    2
# m0 *m2 *m3  + 12*m0 *m2 *σ_1  - 40*m0 *m2 *σ_1 *σ_2 - 160*m0 *m2 *σ_1 *σ_2  -
#
#      8   2    4    3       8   2    3    4       8   2           8      8   __
# 68*m0 *m2 *σ_1 *σ_2  - 4*m0 *m2 *σ_1 *σ_2  + 2*m0 *m2 *σ_1 + 4*m0 *m2*m3 *\/ σ
#
# ___        8      6    3/2        8      6   _____            8      6   _____
# _1  - 16*m0 *m2*m3 *σ_1    - 16*m0 *m2*m3 *\/ σ_1 *σ_2 - 16*m0 *m2*m3 *\/ σ_1
#
#             8      4    5/2        8      4    3/2            8      4    3/2
# *σ_3 + 12*m0 *m2*m3 *σ_1    + 12*m0 *m2*m3 *σ_1   *σ_2 + 16*m0 *m2*m3 *σ_1   *
#
#            8      4   _____    2        8      4   _____                8
# σ_3 + 12*m0 *m2*m3 *\/ σ_1 *σ_2  + 16*m0 *m2*m3 *\/ σ_1 *σ_2*σ_3 + 24*m0 *m2*m
#
#  2    5/2            8      2    3/2    2        8      2    3/2
# 3 *σ_1   *σ_2 + 24*m0 *m2*m3 *σ_1   *σ_2  + 16*m0 *m2*m3 *σ_1   *σ_2*σ_3 + 4*m
#
#  8       5/2    2     8   8    4        8   8    3            8   8    2    2
# 0 *m2*σ_1   *σ_2  + m0 *m3 *σ_1  + 16*m0 *m3 *σ_1 *σ_2 + 36*m0 *m3 *σ_1 *σ_2
#
#        8   8        3     8   8    4       8   6    5        8   6    4
# + 16*m0 *m3 *σ_1*σ_2  + m0 *m3 *σ_2  - 4*m0 *m3 *σ_1  - 64*m0 *m3 *σ_1 *σ_2 -
#
#       8   6    3    2        8   6    2    3       8   6        4       8   4
# 144*m0 *m3 *σ_1 *σ_2  - 64*m0 *m3 *σ_1 *σ_2  - 4*m0 *m3 *σ_1*σ_2  + 6*m0 *m3 *
#
#    6        8   4    5             8   4    4    2        8   4    3    3
# σ_1  + 96*m0 *m3 *σ_1 *σ_2 + 216*m0 *m3 *σ_1 *σ_2  + 96*m0 *m3 *σ_1 *σ_2  + 6*
#
#   8   4    2    4     8   4       8   2    7        8   2    6             8
# m0 *m3 *σ_1 *σ_2  - m0 *m3  - 4*m0 *m3 *σ_1  - 64*m0 *m3 *σ_1 *σ_2 - 144*m0 *m
#
#  2    5    2        8   2    4    3       8   2    3    4       8   2
# 3 *σ_1 *σ_2  - 64*m0 *m3 *σ_1 *σ_2  - 4*m0 *m3 *σ_1 *σ_2  + 2*m0 *m3 *σ_1 + m0
#
# 8    8        8    7            8    6    2        8    5    3     8    4    4
#  *σ_1  + 16*m0 *σ_1 *σ_2 + 36*m0 *σ_1 *σ_2  + 16*m0 *σ_1 *σ_2  + m0 *σ_1 *σ_2
#
#      8    2       7   4   7        7   4   6   _____        7   4   5   2
#  - m0 *σ_1  - 4*m0 *m1 *m2  + 12*m0 *m1 *m2 *\/ σ_1  - 20*m0 *m1 *m2 *m3  + 4*
#
#   7   4   5            7   4   4   2   _____        7   4   4    3/2        7
# m0 *m1 *m2 *σ_1 + 52*m0 *m1 *m2 *m3 *\/ σ_1  - 28*m0 *m1 *m2 *σ_1    + 12*m0 *
#
#   4   3   4       7   4   3    2        7   4   2   4   _____        7   4   2
# m1 *m2 *m3  + 4*m0 *m1 *m2 *σ_1  + 28*m0 *m1 *m2 *m3 *\/ σ_1  - 48*m0 *m1 *m2
#
#    2    3/2        7   4   2    5/2        7   4      6        7   4      4
# *m3 *σ_1    + 20*m0 *m1 *m2 *σ_1    + 12*m0 *m1 *m2*m3  - 12*m0 *m1 *m2*m3 *σ_
#
#         7   4      2    2       7   4       3       7   4   6   _____        7
# 1 + 4*m0 *m1 *m2*m3 *σ_1  - 4*m0 *m1 *m2*σ_1  + 4*m0 *m1 *m3 *\/ σ_1  - 12*m0
#
#    4   4    3/2        7   4   2    5/2       7   4    7/2        7   2   7
# *m1 *m3 *σ_1    + 12*m0 *m1 *m3 *σ_1    - 4*m0 *m1 *σ_1    - 16*m0 *m1 *m2 *m3
#
# 2       7   2   7            7   2   6   2   _____        7   2   6   _____
#   + 8*m0 *m1 *m2 *σ_2 + 40*m0 *m1 *m2 *m3 *\/ σ_1  - 24*m0 *m1 *m2 *\/ σ_1 *σ_
#
#          7   2   5   4       7   2   5   2           7   2   5
# 2 + 16*m0 *m1 *m2 *m3  + 8*m0 *m1 *m2 *m3 *σ_2 - 8*m0 *m1 *m2 *σ_1*σ_2 - 40*m0
#
# 7   2   4   4   _____        7   2   4   2    3/2        7   2   4   2   _____
#  *m1 *m2 *m3 *\/ σ_1  - 24*m0 *m1 *m2 *m3 *σ_1    - 24*m0 *m1 *m2 *m3 *\/ σ_1
#
#             7   2   4   2   _____            7   2   4    3/2            7   2
# *σ_2 + 16*m0 *m1 *m2 *m3 *\/ σ_1 *σ_3 + 56*m0 *m1 *m2 *σ_1   *σ_2 + 16*m0 *m1
#
#    3   6        7   2   3   4            7   2   3   2                7   2
# *m2 *m3  - 40*m0 *m1 *m2 *m3 *σ_2 + 16*m0 *m1 *m2 *m3 *σ_1*σ_2 - 16*m0 *m1 *m2
#
# 3   2               7   2   3    2            7   2   2   6   _____        7
#  *m3 *σ_1*σ_3 - 8*m0 *m1 *m2 *σ_1 *σ_2 - 56*m0 *m1 *m2 *m3 *\/ σ_1  + 80*m0 *m
#
#  2   2   4    3/2        7   2   2   4   _____            7   2   2   4   ____
# 1 *m2 *m3 *σ_1    + 56*m0 *m1 *m2 *m3 *\/ σ_1 *σ_2 + 16*m0 *m1 *m2 *m3 *\/ σ_1
#
# _            7   2   2   2    5/2        7   2   2   2    3/2            7   2
#  *σ_3 - 24*m0 *m1 *m2 *m3 *σ_1    - 16*m0 *m1 *m2 *m3 *σ_1   *σ_2 - 16*m0 *m1
#
#    2   2    3/2            7   2   2    5/2            7   2      8        7
# *m2 *m3 *σ_1   *σ_3 - 40*m0 *m1 *m2 *σ_1   *σ_2 - 16*m0 *m1 *m2*m3  + 32*m0 *m
#
#  2      6            7   2      6            7   2      4    2       7   2
# 1 *m2*m3 *σ_1 + 24*m0 *m1 *m2*m3 *σ_2 - 32*m0 *m1 *m2*m3 *σ_1  - 8*m0 *m1 *m2*
#
#   4                7   2      4                7   2      2    3       7   2
# m3 *σ_1*σ_2 - 16*m0 *m1 *m2*m3 *σ_1*σ_3 + 16*m0 *m1 *m2*m3 *σ_1  + 8*m0 *m1 *m
#
#     2    2            7   2      2    2           7   2       3           7
# 2*m3 *σ_1 *σ_2 + 16*m0 *m1 *m2*m3 *σ_1 *σ_3 + 8*m0 *m1 *m2*σ_1 *σ_2 - 8*m0 *m1
#
# 2   8   _____        7   2   6    3/2        7   2   6   _____            7
#  *m3 *\/ σ_1  + 24*m0 *m1 *m3 *σ_1    + 24*m0 *m1 *m3 *\/ σ_1 *σ_2 - 24*m0 *m1
#
# 2   4    5/2        7   2   4    3/2           7   2   2    7/2       7   2
#  *m3 *σ_1    - 40*m0 *m1 *m3 *σ_1   *σ_2 + 8*m0 *m1 *m3 *σ_1    + 8*m0 *m1 *m3
#
# 2    5/2           7   2    7/2           7   7   4       7   7   2
#  *σ_1   *σ_2 + 8*m0 *m1 *σ_1   *σ_2 - 4*m0 *m2 *m3  + 8*m0 *m2 *m3 *σ_2 - 4*m0
#
# 7   7    2       7   6   4   _____        7   6   2   _____            7   6
#  *m2 *σ_2  + 4*m0 *m2 *m3 *\/ σ_1  - 16*m0 *m2 *m3 *\/ σ_1 *σ_2 + 12*m0 *m2 *\
#
#  _____    2        7   5   6        7   5   4            7   5   4           7
# / σ_1 *σ_2  + 12*m0 *m2 *m3  - 12*m0 *m2 *m3 *σ_1 - 24*m0 *m2 *m3 *σ_2 + 8*m0
#
#    5   2                7   5   2    2       7   5        2        7   4   6
# *m2 *m3 *σ_1*σ_2 + 12*m0 *m2 *m3 *σ_2  + 4*m0 *m2 *σ_1*σ_2  - 36*m0 *m2 *m3 *\
#
#  _____        7   4   4    3/2        7   4   4   _____            7   4   4
# / σ_1  + 44*m0 *m2 *m3 *σ_1    + 64*m0 *m2 *m3 *\/ σ_1 *σ_2 + 16*m0 *m2 *m3 *\
#
#  _____            7   4   2    3/2            7   4   2   _____    2        7
# / σ_1 *σ_3 - 32*m0 *m2 *m3 *σ_1   *σ_2 - 28*m0 *m2 *m3 *\/ σ_1 *σ_2  - 16*m0 *
#
#   4   2   _____                7   4    3/2    2        7   3   8        7   3
# m2 *m3 *\/ σ_1 *σ_2*σ_3 - 28*m0 *m2 *σ_1   *σ_2  - 12*m0 *m2 *m3  + 32*m0 *m2
#
#    6            7   3   6            7   3   4    2        7   3   4
# *m3 *σ_1 + 24*m0 *m2 *m3 *σ_2 - 20*m0 *m2 *m3 *σ_1  - 16*m0 *m2 *m3 *σ_1*σ_2 -
#
#       7   3   4                7   3   4    2       7   3   2    2
#  16*m0 *m2 *m3 *σ_1*σ_3 - 12*m0 *m2 *m3 *σ_2  + 8*m0 *m2 *m3 *σ_1 *σ_2 - 16*m0
#
# 7   3   2        2        7   3   2                   7   3    2    2        7
#  *m2 *m3 *σ_1*σ_2  + 16*m0 *m2 *m3 *σ_1*σ_2*σ_3 + 4*m0 *m2 *σ_1 *σ_2  + 28*m0
#
#    2   8   _____        7   2   6    3/2        7   2   6   _____            7
# *m2 *m3 *\/ σ_1  - 32*m0 *m2 *m3 *σ_1    - 32*m0 *m2 *m3 *\/ σ_1 *σ_2 - 16*m0
#
#    2   6   _____           7   2   4    5/2        7   2   4    3/2
# *m2 *m3 *\/ σ_1 *σ_3 + 4*m0 *m2 *m3 *σ_1    - 64*m0 *m2 *m3 *σ_1   *σ_2 + 16*m
#
#  7   2   4    3/2           7   2   4   _____    2        7   2   4   _____
# 0 *m2 *m3 *σ_1   *σ_3 + 4*m0 *m2 *m3 *\/ σ_1 *σ_2  + 16*m0 *m2 *m3 *\/ σ_1 *σ_
#
#              7   2   2    5/2            7   2   2    3/2    2        7   2
# 2*σ_3 + 64*m0 *m2 *m3 *σ_1   *σ_2 + 64*m0 *m2 *m3 *σ_1   *σ_2  + 16*m0 *m2 *m3
#
# 2    3/2                7   2    5/2    2       7      10        7      8
#  *σ_1   *σ_2*σ_3 + 20*m0 *m2 *σ_1   *σ_2  + 4*m0 *m2*m3   - 20*m0 *m2*m3 *σ_1
#
#       7      8            7      6    2       7      6                7      6
# - 8*m0 *m2*m3 *σ_2 + 28*m0 *m2*m3 *σ_1  + 8*m0 *m2*m3 *σ_1*σ_2 + 16*m0 *m2*m3
#
#                7      6    2        7      4    3        7      4    2
# *σ_1*σ_3 + 4*m0 *m2*m3 *σ_2  - 12*m0 *m2*m3 *σ_1  + 24*m0 *m2*m3 *σ_1 *σ_2 - 1
#
#     7      4    2            7      4        2        7      4
# 6*m0 *m2*m3 *σ_1 *σ_3 + 12*m0 *m2*m3 *σ_1*σ_2  - 16*m0 *m2*m3 *σ_1*σ_2*σ_3 - 2
#
#     7      2    3            7      2    2    2        7      2    2
# 4*m0 *m2*m3 *σ_1 *σ_2 - 12*m0 *m2*m3 *σ_1 *σ_2  - 16*m0 *m2*m3 *σ_1 *σ_2*σ_3 -
#
#      7       3    2       7   10   _____        7   8    3/2        7   8   __
#  4*m0 *m2*σ_1 *σ_2  + 4*m0 *m3  *\/ σ_1  - 12*m0 *m3 *σ_1    - 16*m0 *m3 *\/ σ
#
# ___            7   6    5/2        7   6    3/2            7   6   _____    2
# _1 *σ_2 + 12*m0 *m3 *σ_1    + 16*m0 *m3 *σ_1   *σ_2 + 12*m0 *m3 *\/ σ_1 *σ_2
#
#       7   4    7/2        7   4    5/2            7   4    3/2    2        7
# - 4*m0 *m3 *σ_1    + 16*m0 *m3 *σ_1   *σ_2 + 12*m0 *m3 *σ_1   *σ_2  - 16*m0 *m
#
#  2    7/2            7   2    5/2    2       7    7/2    2       6   8   10
# 3 *σ_1   *σ_2 - 20*m0 *m3 *σ_1   *σ_2  - 4*m0 *σ_1   *σ_2  - 4*m0 *m1 *m2   +
#
#      6   8   8   2        6   8   8           6   8   8            6   8   6
# 16*m0 *m1 *m2 *m3  + 16*m0 *m1 *m2 *σ_1 - 4*m0 *m1 *m2 *σ_2 - 24*m0 *m1 *m2 *m
#
#  4        6   8   6   2            6   8   6   2            6   8   6    2
# 3  - 16*m0 *m1 *m2 *m3 *σ_1 + 16*m0 *m1 *m2 *m3 *σ_2 - 24*m0 *m1 *m2 *σ_1  + 1
#
#     6   8   6                6   8   4   6        6   8   4   4            6
# 6*m0 *m1 *m2 *σ_1*σ_2 + 16*m0 *m1 *m2 *m3  - 16*m0 *m1 *m2 *m3 *σ_1 - 24*m0 *m
#
#  8   4   4            6   8   4   2    2        6   8   4   2                6
# 1 *m2 *m3 *σ_2 - 16*m0 *m1 *m2 *m3 *σ_1  - 16*m0 *m1 *m2 *m3 *σ_1*σ_2 + 16*m0
#
#    8   4    3        6   8   4    2           6   8   2   8        6   8   2
# *m1 *m2 *σ_1  - 24*m0 *m1 *m2 *σ_1 *σ_2 - 4*m0 *m1 *m2 *m3  + 16*m0 *m1 *m2 *m
#
#  6            6   8   2   6            6   8   2   4    2        6   8   2   4
# 3 *σ_1 + 16*m0 *m1 *m2 *m3 *σ_2 - 24*m0 *m1 *m2 *m3 *σ_1  - 16*m0 *m1 *m2 *m3
#
#                 6   8   2   2    3        6   8   2   2    2           6   8
# *σ_1*σ_2 + 16*m0 *m1 *m2 *m3 *σ_1  - 16*m0 *m1 *m2 *m3 *σ_1 *σ_2 - 4*m0 *m1 *m
#
#  2    4        6   8   2    3           6   8   8            6   8   6
# 2 *σ_1  + 16*m0 *m1 *m2 *σ_1 *σ_2 - 4*m0 *m1 *m3 *σ_2 + 16*m0 *m1 *m3 *σ_1*σ_2
#
#         6   8   4    2            6   8   2    3           6   8    4
#  - 24*m0 *m1 *m3 *σ_1 *σ_2 + 16*m0 *m1 *m3 *σ_1 *σ_2 - 4*m0 *m1 *σ_1 *σ_2 - 24
#
#    6   6   12        6   6   10   2         6   6   10            6   6   10
# *m0 *m1 *m2   + 96*m0 *m1 *m2  *m3  + 112*m0 *m1 *m2  *σ_1 - 16*m0 *m1 *m2  *σ
#
#            6   6   8   4         6   6   8   2            6   6   8   2
# _2 - 144*m0 *m1 *m2 *m3  - 160*m0 *m1 *m2 *m3 *σ_1 + 64*m0 *m1 *m2 *m3 *σ_2 -
#
#       6   6   8    2        6   6   8                6   6   8    2        6
# 208*m0 *m1 *m2 *σ_1  + 80*m0 *m1 *m2 *σ_1*σ_2 - 24*m0 *m1 *m2 *σ_2  + 96*m0 *m
#
#  6   6   6        6   6   6   4            6   6   6   2    2         6   6
# 1 *m2 *m3  - 96*m0 *m1 *m2 *m3 *σ_2 - 32*m0 *m1 *m2 *m3 *σ_1  - 128*m0 *m1 *m2
#
# 6   2                6   6   6   2    2         6   6   6    3         6   6
#  *m3 *σ_1*σ_2 + 96*m0 *m1 *m2 *m3 *σ_2  + 192*m0 *m1 *m2 *σ_1  - 160*m0 *m1 *m
#
#  6    2            6   6   6        2       6   6   5   _____        6   6   4
# 2 *σ_1 *σ_2 + 96*m0 *m1 *m2 *σ_1*σ_2  + 4*m0 *m1 *m2 *\/ σ_1  - 24*m0 *m1 *m2
#
#    8        6   6   4   6            6   6   4   6            6   6   4   4
# *m3  + 32*m0 *m1 *m2 *m3 *σ_1 + 64*m0 *m1 *m2 *m3 *σ_2 - 80*m0 *m1 *m2 *m3 *σ_
#
#  2        6   6   4   4                 6   6   4   4    2         6   6   4
# 1  + 32*m0 *m1 *m2 *m3 *σ_1*σ_2 - 144*m0 *m1 *m2 *m3 *σ_2  + 160*m0 *m1 *m2 *m
#
#  2    3        6   6   4   2        2        6   6   4    4         6   6   4
# 3 *σ_1  - 96*m0 *m1 *m2 *m3 *σ_1*σ_2  - 88*m0 *m1 *m2 *σ_1  + 160*m0 *m1 *m2 *
#
#    3             6   6   4    2    2        6   6   3   2   _____        6   6
# σ_1 *σ_2 - 144*m0 *m1 *m2 *σ_1 *σ_2  + 40*m0 *m1 *m2 *m3 *\/ σ_1  - 16*m0 *m1
#
#    3    3/2        6   6   2   8            6   6   2   8            6   6   2
# *m2 *σ_1    + 16*m0 *m1 *m2 *m3 *σ_1 - 16*m0 *m1 *m2 *m3 *σ_2 - 64*m0 *m1 *m2
#
#    6    2        6   6   2   6    2        6   6   2   4    3        6   6   2
# ...
# 1  - 24*m1 *m2 *m3 *σ_1  + 96*m1 *m2 *m3 *σ_1 *σ_2 + 36*m1 *m2 *m3 *σ_1  - 96*
#
#   4   8   4    3             4   8   4    2    2        4   8   2    5
# m1 *m2 *m3 *σ_1 *σ_2 + 216*m1 *m2 *m3 *σ_1 *σ_2  - 24*m1 *m2 *m3 *σ_1  - 96*m1
#
# 4   8   2    4             4   8   2    3    2        4   8   2    2    3
#  *m2 *m3 *σ_1 *σ_2 + 144*m1 *m2 *m3 *σ_1 *σ_2  + 96*m1 *m2 *m3 *σ_1 *σ_2  + 6*
#
#   4   8    6        4   8    5             4   8    4    2        4   8    3
# m1 *m2 *σ_1  + 96*m1 *m2 *σ_1 *σ_2 + 216*m1 *m2 *σ_1 *σ_2  + 96*m1 *m2 *σ_1 *σ
#
#   3       4   8    2    4     4   8        4   7   4    3/2        4   7   2
# _2  + 6*m1 *m2 *σ_1 *σ_2  - m1 *m2  - 12*m1 *m2 *m3 *σ_1    - 24*m1 *m2 *m3 *σ
#
#   5/2        4   7   2    3/2           4   7    7/2        4   7    5/2
# _1    - 40*m1 *m2 *m3 *σ_1   *σ_2 - 4*m1 *m2 *σ_1    + 16*m1 *m2 *σ_1   *σ_2 +
#
#       4   7    3/2    2        4   6   8    2            4   6   6    3
#  12*m1 *m2 *σ_1   *σ_2  - 24*m1 *m2 *m3 *σ_1 *σ_2 + 96*m1 *m2 *m3 *σ_1 *σ_2 -
#
#       4   6   6    2    2         4   6   4    4             4   6   4    3
# 144*m1 *m2 *m3 *σ_1 *σ_2  - 144*m1 *m2 *m3 *σ_1 *σ_2 + 144*m1 *m2 *m3 *σ_1 *σ_
#
#  2         4   6   4    2    3        4   6   2    5             4   6   2
# 2  - 144*m1 *m2 *m3 *σ_1 *σ_2  + 96*m1 *m2 *m3 *σ_1 *σ_2 + 144*m1 *m2 *m3 *σ_1
#
# 4    2        4   6   2    3    3        4   6   2    2    4       4   6   2
#  *σ_2  - 96*m1 *m2 *m3 *σ_1 *σ_2  - 24*m1 *m2 *m3 *σ_1 *σ_2  - 2*m1 *m2 *m3  -
#
#       4   6    6             4   6    5    2         4   6    4    3        4
#  24*m1 *m2 *σ_1 *σ_2 - 144*m1 *m2 *σ_1 *σ_2  - 144*m1 *m2 *σ_1 *σ_2  - 24*m1 *
#
#   6    3    4       4   6           4   6           4   6            4   5   4
# m2 *σ_1 *σ_2  + 2*m1 *m2 *σ_1 + 2*m1 *m2 *σ_2 + 2*m1 *m2 *σ_3 + 36*m1 *m2 *m3
#
#     3/2            4   5   2    5/2            4   5   2    3/2    2        4
# *σ_1   *σ_2 + 24*m1 *m2 *m3 *σ_1   *σ_2 + 24*m1 *m2 *m3 *σ_1   *σ_2  - 20*m1 *
#
#   5    7/2            4   5    5/2    2        4   5    3/2    3        4   4
# m2 *σ_1   *σ_2 - 48*m1 *m2 *σ_1   *σ_2  - 20*m1 *m2 *σ_1   *σ_2  + 36*m1 *m2 *
#
#   8    2    2         4   4   6    3    2        4   4   6    2    3         4
# m3 *σ_1 *σ_2  - 144*m1 *m2 *m3 *σ_1 *σ_2  + 96*m1 *m2 *m3 *σ_1 *σ_2  + 216*m1
#
#    4   4    4    2        4   4   4    3    3        4   4   4    2    4
# *m2 *m3 *σ_1 *σ_2  - 96*m1 *m2 *m3 *σ_1 *σ_2  + 36*m1 *m2 *m3 *σ_1 *σ_2  + 3*m
#
#  4   4   4         4   4   2    5    2        4   4   2    4    3        4   4
# 1 *m2 *m3  - 144*m1 *m2 *m3 *σ_1 *σ_2  - 96*m1 *m2 *m3 *σ_1 *σ_2  + 24*m1 *m2
#
#    2    3    4       4   4   2           4   4   2           4   4   2
# *m3 *σ_1 *σ_2  + 2*m1 *m2 *m3 *σ_1 + 2*m1 *m2 *m3 *σ_2 - 2*m1 *m2 *m3 *σ_3 + 3
#
#     4   4    6    2        4   4    5    3        4   4    4    4     4   4
# 6*m1 *m2 *σ_1 *σ_2  + 96*m1 *m2 *σ_1 *σ_2  + 36*m1 *m2 *σ_1 *σ_2  - m1 *m2 *σ_
#
#  2       4   4               4   4             4   4    2       4   4
# 1  - 4*m1 *m2 *σ_1*σ_2 - 2*m1 *m2 *σ_1*σ_3 - m1 *m2 *σ_2  - 2*m1 *m2 *σ_2*σ_3
#
#        4   3   4    3/2    2        4   3   2    5/2    2       4   3   2    3
# - 36*m1 *m2 *m3 *σ_1   *σ_2  + 24*m1 *m2 *m3 *σ_1   *σ_2  + 8*m1 *m2 *m3 *σ_1
#
# /2    3        4   3    7/2    2        4   3    5/2    3       4   3    3/2
#   *σ_2  + 12*m1 *m2 *σ_1   *σ_2  + 16*m1 *m2 *σ_1   *σ_2  + 8*m1 *m2 *σ_1   *σ
#
#   4        4   2   8    2    3        4   2   6    3    3        4   2   6
# _2  - 24*m1 *m2 *m3 *σ_1 *σ_2  + 96*m1 *m2 *m3 *σ_1 *σ_2  - 24*m1 *m2 *m3 *σ_1
#
# 2    4         4   2   4    4    3        4   2   4    3    4       4   2   4
#  *σ_2  - 144*m1 *m2 *m3 *σ_1 *σ_2  + 24*m1 *m2 *m3 *σ_1 *σ_2  - 4*m1 *m2 *m3 *
#
#            4   2   2    5    3        4   2   2    4    4       4   2   2
# σ_2 + 96*m1 *m2 *m3 *σ_1 *σ_2  + 24*m1 *m2 *m3 *σ_1 *σ_2  - 2*m1 *m2 *m3 *σ_1*
#
#           4   2   2                4   2    6    3        4   2    5    4
# σ_2 + 2*m1 *m2 *m3 *σ_2*σ_3 - 24*m1 *m2 *σ_1 *σ_2  - 24*m1 *m2 *σ_1 *σ_2  + 2*
#
#   4   2    2           4   2        2       4   2                    4      4
# m1 *m2 *σ_1 *σ_2 + 2*m1 *m2 *σ_1*σ_2  + 2*m1 *m2 *σ_1*σ_2*σ_3 + 12*m1 *m2*m3 *
#
#    3/2    3        4      2    5/2    3       4      2    3/2    4        4
# σ_1   *σ_2  - 24*m1 *m2*m3 *σ_1   *σ_2  - 8*m1 *m2*m3 *σ_1   *σ_2  + 12*m1 *m2
#
#     7/2    3       4       5/2    4       4   8    2    4        4   6    3
# *σ_1   *σ_2  + 8*m1 *m2*σ_1   *σ_2  + 6*m1 *m3 *σ_1 *σ_2  - 24*m1 *m3 *σ_1 *σ_
#
#  4        4   4    4    4     4   4    2        4   2    5    4       4    6
# 2  + 36*m1 *m3 *σ_1 *σ_2  + m1 *m3 *σ_2  - 24*m1 *m3 *σ_1 *σ_2  + 6*m1 *σ_1 *σ
#
#   4     4    2    2       2   16    3        2   14   2    3        2   14
# _2  - m1 *σ_1 *σ_2  - 4*m1 *m2  *σ_1  + 16*m1 *m2  *m3 *σ_1  + 16*m1 *m2  *σ_1
#
# 4        2   14    3            2   12   4    3        2   12   2    4
#   + 16*m1 *m2  *σ_1 *σ_2 - 24*m1 *m2  *m3 *σ_1  - 16*m1 *m2  *m3 *σ_1  - 64*m1
#
# 2   12   2    3            2   12    5        2   12    4            2   12
#  *m2  *m3 *σ_1 *σ_2 - 24*m1 *m2  *σ_1  - 64*m1 *m2  *σ_1 *σ_2 - 24*m1 *m2  *σ_
#
#  3    2        2   10   6    3        2   10   4    4        2   10   4    3
# 1 *σ_2  + 16*m1 *m2  *m3 *σ_1  - 16*m1 *m2  *m3 *σ_1  + 96*m1 *m2  *m3 *σ_1 *σ
#
#           2   10   2    5        2   10   2    4            2   10   2    3
# _2 - 16*m1 *m2  *m3 *σ_1  + 64*m1 *m2  *m3 *σ_1 *σ_2 + 96*m1 *m2  *m3 *σ_1 *σ_
#
#  2        2   10    6        2   10    5            2   10    4    2        2
# 2  + 16*m1 *m2  *σ_1  + 96*m1 *m2  *σ_1 *σ_2 + 96*m1 *m2  *σ_1 *σ_2  + 16*m1 *
#
#   10    3    3       2   9   2    5/2       2   9    5/2           2   8   8
# m2  *σ_1 *σ_2  - 8*m1 *m2 *m3 *σ_1    + 8*m1 *m2 *σ_1   *σ_2 - 4*m1 *m2 *m3 *σ
#
#   3        2   8   6    4        2   8   6    3            2   8   4    5
# _1  + 16*m1 *m2 *m3 *σ_1  - 64*m1 *m2 *m3 *σ_1 *σ_2 - 24*m1 *m2 *m3 *σ_1  + 64
#
#    2   8   4    4             2   8   4    3    2        2   8   2    6
# *m1 *m2 *m3 *σ_1 *σ_2 - 144*m1 *m2 *m3 *σ_1 *σ_2  + 16*m1 *m2 *m3 *σ_1  + 64*m
#
#  2   8   2    5            2   8   2    4    2        2   8   2    3    3
# 1 *m2 *m3 *σ_1 *σ_2 - 96*m1 *m2 *m3 *σ_1 *σ_2  - 64*m1 *m2 *m3 *σ_1 *σ_2  - 4*
#
#   2   8    7        2   8    6             2   8    5    2        2   8    4
# m1 *m2 *σ_1  - 64*m1 *m2 *σ_1 *σ_2 - 144*m1 *m2 *σ_1 *σ_2  - 64*m1 *m2 *σ_1 *σ
#
#   3       2   8    3    4       2   8            2   7   4    5/2       2   7
# _2  - 4*m1 *m2 *σ_1 *σ_2  + 2*m1 *m2 *σ_1 + 12*m1 *m2 *m3 *σ_1    + 8*m1 *m2 *
#
#   2    7/2       2   7   2    5/2            2   7    7/2            2   7
# m3 *σ_1    + 8*m1 *m2 *m3 *σ_1   *σ_2 - 16*m1 *m2 *σ_1   *σ_2 - 20*m1 *m2 *σ_1
#
# 5/2    2        2   6   8    3            2   6   6    4            2   6   6
#    *σ_2  + 16*m1 *m2 *m3 *σ_1 *σ_2 - 64*m1 *m2 *m3 *σ_1 *σ_2 + 96*m1 *m2 *m3 *
#
#    3    2        2   6   4    5            2   6   4    4    2        2   6
# σ_1 *σ_2  + 96*m1 *m2 *m3 *σ_1 *σ_2 - 96*m1 *m2 *m3 *σ_1 *σ_2  + 96*m1 *m2 *m3
#
# 4    3    3        2   6   2    6            2   6   2    5    2        2   6
#  *σ_1 *σ_2  - 64*m1 *m2 *m3 *σ_1 *σ_2 - 96*m1 *m2 *m3 *σ_1 *σ_2  + 64*m1 *m2 *
#
#   2    4    3        2   6   2    3    4       2   6   2            2   6    7
# m3 *σ_1 *σ_2  + 16*m1 *m2 *m3 *σ_1 *σ_2  + 6*m1 *m2 *m3 *σ_1 + 16*m1 *m2 *σ_1
#
#             2   6    6    2        2   6    5    3        2   6    4    4
# *σ_2 + 96*m1 *m2 *σ_1 *σ_2  + 96*m1 *m2 *σ_1 *σ_2  + 16*m1 *m2 *σ_1 *σ_2  - 4*
#
#   2   6    2       2   6               2   6                2   5   4    5/2
# m1 *m2 *σ_1  - 4*m1 *m2 *σ_1*σ_2 - 6*m1 *m2 *σ_1*σ_3 - 36*m1 *m2 *m3 *σ_1   *σ
#
#          2   5   2    7/2            2   5   2    5/2    2       2   5    9/2
# _2 + 8*m1 *m2 *m3 *σ_1   *σ_2 + 24*m1 *m2 *m3 *σ_1   *σ_2  + 8*m1 *m2 *σ_1   *
#
#            2   5    7/2    2        2   5    5/2    3        2   4   8    3
# σ_2 + 16*m1 *m2 *σ_1   *σ_2  + 12*m1 *m2 *σ_1   *σ_2  - 24*m1 *m2 *m3 *σ_1 *σ_
#
#  2        2   4   6    4    2        2   4   6    3    3         2   4   4
# 2  + 96*m1 *m2 *m3 *σ_1 *σ_2  - 64*m1 *m2 *m3 *σ_1 *σ_2  - 144*m1 *m2 *m3 *σ_1
#
# 5    2        2   4   4    4    3        2   4   4    3    4        2   4   2
#  *σ_2  + 64*m1 *m2 *m3 *σ_1 *σ_2  - 24*m1 *m2 *m3 *σ_1 *σ_2  + 96*m1 *m2 *m3 *
#
#    6    2        2   4   2    5    3        2   4   2    4    4       2   4
# σ_1 *σ_2  + 64*m1 *m2 *m3 *σ_1 *σ_2  - 16*m1 *m2 *m3 *σ_1 *σ_2  - 6*m1 *m2 *m3
#
# 2    2       2   4   2               2   4   2                2   4    7    2
#  *σ_1  - 8*m1 *m2 *m3 *σ_1*σ_2 - 6*m1 *m2 *m3 *σ_1*σ_3 - 24*m1 *m2 *σ_1 *σ_2
#
#        2   4    6    3        2   4    5    4       2   4    3       2   4
# - 64*m1 *m2 *σ_1 *σ_2  - 24*m1 *m2 *σ_1 *σ_2  + 2*m1 *m2 *σ_1  + 8*m1 *m2 *σ_1
#
# 2           2   4    2           2   4        2       2   4
#  *σ_2 + 6*m1 *m2 *σ_1 *σ_3 + 2*m1 *m2 *σ_1*σ_2  + 8*m1 *m2 *σ_1*σ_2*σ_3 + 4*m1
#
# 2   4        2        2   3   4    5/2    2        2   3   2    7/2    2
#  *m2 *σ_1*σ_3  + 36*m1 *m2 *m3 *σ_1   *σ_2  - 40*m1 *m2 *m3 *σ_1   *σ_2  - 40*
#
#   2   3   2    5/2    3       2   3    9/2    2        2   3    7/2    3
# m1 *m2 *m3 *σ_1   *σ_2  + 4*m1 *m2 *σ_1   *σ_2  + 16*m1 *m2 *σ_1   *σ_2  + 4*m
#
#  2   3    5/2    4        2   2   8    3    3        2   2   6    4    3
# 1 *m2 *σ_1   *σ_2  + 16*m1 *m2 *m3 *σ_1 *σ_2  - 64*m1 *m2 *m3 *σ_1 *σ_2  + 16*
#
#   2   2   6    3    4        2   2   4    5    3        2   2   4    4    4
# m1 *m2 *m3 *σ_1 *σ_2  + 96*m1 *m2 *m3 *σ_1 *σ_2  - 16*m1 *m2 *m3 *σ_1 *σ_2  -
#
#      2   2   2    6    3        2   2   2    5    4       2   2   2    2
# 64*m1 *m2 *m3 *σ_1 *σ_2  - 16*m1 *m2 *m3 *σ_1 *σ_2  + 8*m1 *m2 *m3 *σ_1 *σ_2 +
#
#      2   2   2        2       2   2   2                    2   2    7    3
#  2*m1 *m2 *m3 *σ_1*σ_2  + 8*m1 *m2 *m3 *σ_1*σ_2*σ_3 + 16*m1 *m2 *σ_1 *σ_2  + 1
#
#     2   2    6    4       2   2    3           2   2    2    2       2   2
# 6*m1 *m2 *σ_1 *σ_2  - 4*m1 *m2 *σ_1 *σ_2 - 4*m1 *m2 *σ_1 *σ_2  - 8*m1 *m2 *σ_1
#
# 2               2   2        2           2   2            2        2      4
#  *σ_2*σ_3 - 2*m1 *m2 *σ_1*σ_2 *σ_3 - 4*m1 *m2 *σ_1*σ_2*σ_3  - 12*m1 *m2*m3 *σ_
#
#  5/2    3        2      2    7/2    3        2      2    5/2    4        2
# 1   *σ_2  + 24*m1 *m2*m3 *σ_1   *σ_2  + 16*m1 *m2*m3 *σ_1   *σ_2  - 12*m1 *m2*
#
#    9/2    3        2       7/2    4       2       5/2    5       2   8    3
# σ_1   *σ_2  - 16*m1 *m2*σ_1   *σ_2  - 4*m1 *m2*σ_1   *σ_2  - 4*m1 *m3 *σ_1 *σ_
#
#  4        2   6    4    4        2   4    5    4        2   2    6    4
# 2  + 16*m1 *m3 *σ_1 *σ_2  - 24*m1 *m3 *σ_1 *σ_2  + 16*m1 *m3 *σ_1 *σ_2  - 2*m1
#
# 2   2    2    2       2   2        2           2    7    4       2    3    2
#  *m3 *σ_1 *σ_2  - 2*m1 *m3 *σ_1*σ_2 *σ_3 - 4*m1 *σ_1 *σ_2  + 2*m1 *σ_1 *σ_2  +
#
#      2    2    2         16    4       14   2    4       14    5       14    4
#  2*m1 *σ_1 *σ_2 *σ_3 + m2  *σ_1  - 4*m2  *m3 *σ_1  - 4*m2  *σ_1  - 4*m2  *σ_1
#
#            12   4    4       12   2    5        12   2    4           12    6
# *σ_2 + 6*m2  *m3 *σ_1  + 4*m2  *m3 *σ_1  + 16*m2  *m3 *σ_1 *σ_2 + 6*m2  *σ_1
#
#        12    5           12    4    2       10   6    4       10   4    5
# + 16*m2  *σ_1 *σ_2 + 6*m2  *σ_1 *σ_2  - 4*m2  *m3 *σ_1  + 4*m2  *m3 *σ_1  - 24
#
#    10   4    4           10   2    6        10   2    5            10   2    4
# *m2  *m3 *σ_1 *σ_2 + 4*m2  *m3 *σ_1  - 16*m2  *m3 *σ_1 *σ_2 - 24*m2  *m3 *σ_1
#
#     2       10    7        10    6            10    5    2       10    4    3
# *σ_2  - 4*m2  *σ_1  - 24*m2  *σ_1 *σ_2 - 24*m2  *σ_1 *σ_2  - 4*m2  *σ_1 *σ_2
#
#     8   8    4       8   6    5        8   6    4           8   4    6
# + m2 *m3 *σ_1  - 4*m2 *m3 *σ_1  + 16*m2 *m3 *σ_1 *σ_2 + 6*m2 *m3 *σ_1  - 16*m2
#
# 8   4    5            8   4    4    2       8   2    7        8   2    6
#  *m3 *σ_1 *σ_2 + 36*m2 *m3 *σ_1 *σ_2  - 4*m2 *m3 *σ_1  - 16*m2 *m3 *σ_1 *σ_2 +
#
#       8   2    5    2        8   2    4    3     8    8        8    7
#  24*m2 *m3 *σ_1 *σ_2  + 16*m2 *m3 *σ_1 *σ_2  + m2 *σ_1  + 16*m2 *σ_1 *σ_2 + 36
#
#    8    6    2        8    5    3     8    4    4     8    2       7   4    7/
# *m2 *σ_1 *σ_2  + 16*m2 *σ_1 *σ_2  + m2 *σ_1 *σ_2  - m2 *σ_1  - 4*m2 *m3 *σ_1
#
# 2       7   2    7/2           7    7/2    2       6   8    4            6   6
#   + 8*m2 *m3 *σ_1   *σ_2 - 4*m2 *σ_1   *σ_2  - 4*m2 *m3 *σ_1 *σ_2 + 16*m2 *m3
#
#     5            6   6    4    2        6   4    6            6   4    5    2
# *σ_1 *σ_2 - 24*m2 *m3 *σ_1 *σ_2  - 24*m2 *m3 *σ_1 *σ_2 + 24*m2 *m3 *σ_1 *σ_2
#
#        6   4    4    3        6   2    7            6   2    6    2        6
# - 24*m2 *m3 *σ_1 *σ_2  + 16*m2 *m3 *σ_1 *σ_2 + 24*m2 *m3 *σ_1 *σ_2  - 16*m2 *m
#
#  2    5    3       6   2    4    4       6   2    2       6    8            6
# 3 *σ_1 *σ_2  - 4*m2 *m3 *σ_1 *σ_2  - 4*m2 *m3 *σ_1  - 4*m2 *σ_1 *σ_2 - 24*m2 *
#
#    7    2        6    6    3       6    5    4       6    3       6    2
# σ_1 *σ_2  - 24*m2 *σ_1 *σ_2  - 4*m2 *σ_1 *σ_2  + 2*m2 *σ_1  + 2*m2 *σ_1 *σ_2 +
#
#      6    2            5   4    7/2           5   2    9/2            5   2
#  4*m2 *σ_1 *σ_3 + 12*m2 *m3 *σ_1   *σ_2 - 8*m2 *m3 *σ_1   *σ_2 - 24*m2 *m3 *σ_
#
#  7/2    2       5    9/2    2        5    7/2    3       4   8    4    2
# 1   *σ_2  + 8*m2 *σ_1   *σ_2  + 12*m2 *σ_1   *σ_2  + 6*m2 *m3 *σ_1 *σ_2  - 24*
#
#   4   6    5    2        4   6    4    3        4   4    6    2        4   4
# m2 *m3 *σ_1 *σ_2  + 16*m2 *m3 *σ_1 *σ_2  + 36*m2 *m3 *σ_1 *σ_2  - 16*m2 *m3 *σ
#
#   5    3       4   4    4    4       4   4    2        4   2    7    2
# _1 *σ_2  + 6*m2 *m3 *σ_1 *σ_2  - 3*m2 *m3 *σ_1  - 24*m2 *m3 *σ_1 *σ_2  - 16*m2
#
# 4   2    6    3       4   2    5    4       4   2    3       4   2    2
#  *m3 *σ_1 *σ_2  + 4*m2 *m3 *σ_1 *σ_2  + 4*m2 *m3 *σ_1  + 6*m2 *m3 *σ_1 *σ_2 +
#
#     4   2    2           4    8    2        4    7    3       4    6    4
# 8*m2 *m3 *σ_1 *σ_3 + 6*m2 *σ_1 *σ_2  + 16*m2 *σ_1 *σ_2  + 6*m2 *σ_1 *σ_2  - m2
#
# 4    4       4    3           4    3         4    2    2       4    2
#  *σ_1  - 4*m2 *σ_1 *σ_2 - 4*m2 *σ_1 *σ_3 - m2 *σ_1 *σ_2  - 6*m2 *σ_1 *σ_2*σ_3
#
#       4    2    2        3   4    7/2    2        3   2    9/2    2        3
# - 4*m2 *σ_1 *σ_3  - 12*m2 *m3 *σ_1   *σ_2  + 16*m2 *m3 *σ_1   *σ_2  + 24*m2 *m
#
#  2    7/2    3       3    11/2    2        3    9/2    3        3    7/2    4
# 3 *σ_1   *σ_2  - 4*m2 *σ_1    *σ_2  - 16*m2 *σ_1   *σ_2  - 12*m2 *σ_1   *σ_2
#
#       2   8    4    3        2   6    5    3       2   6    4    4        2
# - 4*m2 *m3 *σ_1 *σ_2  + 16*m2 *m3 *σ_1 *σ_2  - 4*m2 *m3 *σ_1 *σ_2  - 24*m2 *m3
#
# 4    6    3       2   4    5    4       2   4    2            2   2    7    3
#  *σ_1 *σ_2  + 4*m2 *m3 *σ_1 *σ_2  + 4*m2 *m3 *σ_1 *σ_2 + 16*m2 *m3 *σ_1 *σ_2
#
#       2   2    6    4       2   2    3           2   2    2    2        2   2
# + 4*m2 *m3 *σ_1 *σ_2  - 6*m2 *m3 *σ_1 *σ_2 - 2*m2 *m3 *σ_1 *σ_2  - 10*m2 *m3 *
#
#    2               2    8    3       2    7    4       2    4           2    3
# σ_1 *σ_2*σ_3 - 4*m2 *σ_1 *σ_2  - 4*m2 *σ_1 *σ_2  + 2*m2 *σ_1 *σ_2 + 2*m2 *σ_1
#
#     2       2    3               2    2    2           2    2        2
# *σ_2  + 6*m2 *σ_1 *σ_2*σ_3 + 2*m2 *σ_1 *σ_2 *σ_3 + 4*m2 *σ_1 *σ_2*σ_3  + 4*m2*
#
#   4    7/2    3          2    9/2    3          2    7/2    4           11/2
# m3 *σ_1   *σ_2  - 8*m2*m3 *σ_1   *σ_2  - 8*m2*m3 *σ_1   *σ_2  + 4*m2*σ_1    *σ
#
#   3           9/2    4           7/2    5     8    4    4       6    5    4
# _2  + 8*m2*σ_1   *σ_2  + 4*m2*σ_1   *σ_2  + m3 *σ_1 *σ_2  - 4*m3 *σ_1 *σ_2  +
#
#     4    6    4     4    2    2       2    7    4       2    3    2       2
# 6*m3 *σ_1 *σ_2  - m3 *σ_1 *σ_2  - 4*m3 *σ_1 *σ_2  + 2*m3 *σ_1 *σ_2  + 2*m3 *σ_
#
#  2    2          8    4      4    2        3    2
# 1 *σ_2 *σ_3 + σ_1 *σ_2  - σ_1 *σ_2  - 2*σ_1 *σ_2 *σ_3
